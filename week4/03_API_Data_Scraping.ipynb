# %% [markdown]
# Big Data And Society: Lab 3
# =====

# %% [markdown]
# # APIs and Data Scraping: Getting Twitter Data

# %% [markdown]
# ### 0. Set up a Twitter Application
#
# This week we are going to scrape data from the Twitter API and make some plots! We are going to use the Twitter REST API, which lets us query and retreive samples of Tweets. To do this, you need API keys that are associated with your account. Your API keys are secret and unique to you and only you, and they gives you access to Twitter data through the API.
#
# There are a couple of ways to get Twitter data, the REST API is just one of them. The others are to set up a Streamer (which streams real time tweets), or to access the Firehose (this means everything!). Read [this article](https://brightplanet.com/2013/06/twitter-firehose-vs-twitter-api-whats-the-difference-and-why-should-you-care/) for a nice comparison between the methods.
#
# The Twitter REST API is best place to start and what we will use in class. Follow the following steps to get your keys.
#
# * Create a twitter account if you do not already have one.
# * Go to [https://apps.twitter.com/](https://apps.twitter.com/) and log in with your twitter credentials.
# * Click **"Create New App"** in the upper right corner
# * Fill out the form, give it a name like **data_getter_yourname** and a description, agree to the terms, and click **"Create your Twitter application"** *Note: The form will ask for a website. You can put the github.io page you made as the URL. **It is OK for your callback URL to be blank.***
# * In the next page, click on **Keys and Access Tokens** tab, and copy your "Consumer Key (API Key)" and "Consumer Key (API Secret)".
#
# We need a Python file that will contain the **Twitter** keys. It is never a good idea to host these keys on a public website like **github**, so one way to keep them private is importing the keys as a variable from a separate, untracked file. Open your text editor, and in the materials for the week, *PASTE* these keys into the **twitter-keys.py** file and save the file. Using this method, we can then import the keys and use them on a repeated basis, and we can choose not to put this file on Github. **Make sure they are saved as strings!**
#
# **!!IMPORTANT NOTE!! NEVER SAVE YOUR TWITTER_KEY.PY FILE TO GITHUB. IF YOU DO, PEOPLE CAN SEE YOUR KEYS AND USE THEM. KEEP THESE ON YOUR MACHINE.**

# %% [markdown]
# ### 1. Importing the Libraries and Twitter Keys
#
# We will be using **Twython**, a Python library that provides wrappers around Twitter's API. To install **Twython** on a terminal or the command line, run the following command:
#
# ```
# pip install twython
# ```
#
# We also need to import the keys we just got from Twitter to be accessible to our code. View the contents of **twitter_key.py** to see your keys. These should both be strings.
#
# ```
# # In the file you should define two variables:
# api_key = "your twitter key"
# api_secret = "your twitter secret"
# ```
#
# Import the libraries:

# %%
# Import libraries
import json
import time
import threading
from datetime import datetime
from twython import Twython

# Imports the keys from the python file
from twitter_key import api_key, api_secret

# %% [markdown]
# ### 2. Set Up Twython, Get an OAuth2 Token, and Create your Twython Object
#
# In this next step, assign the keys to variables and set up our instance of Twython to work with your account.
#
# Doing this requires our authentication with Twitter using our keys. Twitter uses something called [OAuth](https://dev.twitter.com/oauth) for API authentication. There are two types of OAuth authentication. OAuth1 provides user authentication to the API, and is required to post tweets and issue requests on behalf of users. OAuth 2 is [application-only authentication](https://dev.twitter.com/oauth/application-only), and has higher rate limits but doesn't allow you to post on users behalf. Because we can get more tweets using it, we are going to use OAuth2.
#
# **OAuth 2 requires a Third Access token you must request using the API. This next step will set everything up for us.**
#
# In the last part of this, we create a **Twython** object and call it **my_twython**; this object simplifies the access to the [Twitter API](https://dev.twitter.com/overview/documentation), and provides methods for accessing the API’s endpoints. The first function fetches tweets with a given query at a given lat-long. We will be using the search parameters to hit the APIs endpoint. We need to provide the lat/lon of the centroid of the area we want to query, maximum number of tweets to return, and area within the centroid to search for, among others.

# %%
# Assigns the keys to the variables
APP_KEY = api_key
APP_SECRET = api_secret

# Create a Twython object called Twitter
# Set this up using your Twitter Keys
# Say we are going to use OAuth 2
twython_setup = Twython(APP_KEY, APP_SECRET, oauth_version=2)

# Get an OAuth2 access token, save as variable so we can launch our 
OAUTH2_ACCESS_TOKEN = twython_setup.obtain_access_token()

# Create a Twython Object we will use for our access to the API
my_twython = Twython(APP_KEY, access_token=OAUTH2_ACCESS_TOKEN)

# %% [markdown]
# For reference, the Twython documentation and all available commands can be found here. [https://twython.readthedocs.io/en/latest/usage/starting_out.html](https://twython.readthedocs.io/en/latest/usage/starting_out.html)

# %% [markdown]
# ### 3. Query the Twitter API to get Tweets at a Location
#
# Next, let's do a search and get some tweets! Specifically, set up a function that will use the **search** API. Read more about the **search** API [here](https://dev.twitter.com/rest/reference/get/search/tweets).
#
# The **Search API** can take many parameters for querying tweets. Twitter has a nice page of what you can use as query parameters here [https://dev.twitter.com/rest/public/search](https://dev.twitter.com/rest/public/search).
#
# The Twitter API has rate limits that limit how quickly you can download data. This is to try to lighten the load on their servers. We are using the Search API with **OAuth2 (Application) Access** - which limits us to **450 in 15 minutes** Read about the [Rate Limits](https://dev.twitter.com/rest/public/rate-limiting) here. This means, in our following steps, always follow the guideline that you will not be able to get more than 450 tweets in 15 minutes, or Twitter might lock your access.

# %%
# Input the search term you want to search on
search_term='' # SET A SEARCH TERM LIKE 'TRUMP'
# CAN LEAVE search_term BLANK IF YOU WANT ALL TWEETS NEAR A SPECIFIC LOCATION
# Setup a Lat Lon
latlong=[40.261455,-76.882553] # Downtown Harrisburg, PA - Capital of Pennsylvania
# Setup a search distance
distance='25mi'
# Set result type (can be 'recent', 'popular', or 'mixed')
type_of_result='recent'
# Set number of results (up to 100, remember you can only get 450 in 15 minutes)
number_of_tweets=15


# Fetches tweets with a given query at a given lat-long.
def get_tweets_by_location( latlong=None ):
    # Uses the search function to hit the APIs endpoints and look for recent tweets within the area
    results = my_twython.search(q=search_term, geocode=str(latlong[0])+','+str(latlong[1])+','+ distance, result_type=type_of_result, count=number_of_tweets)
    # Returns the only the statuses from the resulting JSON
    return results['statuses']

# test run our function
get_tweets_by_location(latlong)
# Out:
# [{'contributors': None,
#   'coordinates': None,
#   'created_at': 'Sun Mar 05 23:36:33 +0000 2017',
#   'entities': {'hashtags': [], 'symbols': [], 'urls': [], 'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838533724845273088,
#   'id_str': '838533724845273088',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': "Barb is making lasagna, it's a wonderful day 😍",
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Mon Jun 13 15:42:55 +0000 2011',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': "Jeremy | Penn State University '19",
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 11200,
#    'follow_request_sent': None,
#    'followers_count': 674,
#    'following': None,
#    'friends_count': 229,
#    'geo_enabled': True,
#    'has_extended_profile': True,
#    'id': 316523466,
#    'id_str': '316523466',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 4,
#    'location': 'York, PA',
#    'name': 'haley',
#    'notifications': None,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/394982842/love.jpg',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/394982842/love.jpg',
#    'profile_background_tile': True,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/316523466/1487527893',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/832261215221067776/r9wmeKua_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/832261215221067776/r9wmeKua_normal.jpg',
#    'profile_link_color': '89C9FA',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'haleey_fayee',
#    'statuses_count': 52766,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Sun Mar 05 23:36:32 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'fb.me/8vG1A9FR5',
#      'expanded_url': 'http://fb.me/8vG1A9FR5',
#      'indices': [85, 108],
#      'url': 'https://t.co/eLVYgdfixj'}],
#    'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838533719216500736,
#   'id_str': '838533719216500736',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://www.facebook.com/twitter" rel="nofollow">Facebook</a>',
#   'text': 'We want your kitties to enjoy coming to see us just as much as we enjoy seeing them! https://t.co/eLVYgdfixj',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Wed Aug 29 14:45:11 +0000 2012',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Established in 1944, Lockwillow Avenue Animal Clinic is still serving the Harrisburg community with innovative solutions to all of your pets needs.',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'lockwillow.com',
#        'expanded_url': 'http://www.lockwillow.com',
#        'indices': [0, 23],
#        'url': 'https://t.co/t4cFEdk6To'}]}},
#    'favourites_count': 24,
#    'follow_request_sent': None,
#    'followers_count': 71,
#    'following': None,
#    'friends_count': 265,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 789490880,
#    'id_str': '789490880',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 0,
#    'location': 'Harrisburg, PA',
#    'name': 'LockwillowAve Animal',
#    'notifications': None,
#    'profile_background_color': 'EBEBEB',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme7/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme7/bg.gif',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/789490880/1426292978',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/818240078237597696/1owiOEDe_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/818240078237597696/1owiOEDe_normal.jpg',
#    'profile_link_color': '990000',
#    'profile_sidebar_border_color': 'DFDFDF',
#    'profile_sidebar_fill_color': 'F3F3F3',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'MarkGuise',
#    'statuses_count': 494,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'none',
#    'url': 'https://t.co/t4cFEdk6To',
#    'utc_offset': -18000,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Sun Mar 05 23:36:28 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 2759118644,
#      'id_str': '2759118644',
#      'indices': [0, 12],
#      'name': 'Fi',
#      'screen_name': 'FleaBagLady'},
#     {'id': 17174257,
#      'id_str': '17174257',
#      'indices': [13, 20],
#      'name': 'JoodiG',
#      'screen_name': 'JoodiG'},
#     {'id': 44212339,
#      'id_str': '44212339',
#      'indices': [21, 34],
#      'name': 'Dr Marewa Glover',
#      'screen_name': 'MarewaGlover'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838533702988742656,
#   'id_str': '838533702988742656',
#   'in_reply_to_screen_name': 'FleaBagLady',
#   'in_reply_to_status_id': 838502641357447169,
#   'in_reply_to_status_id_str': '838502641357447169',
#   'in_reply_to_user_id': 2759118644,
#   'in_reply_to_user_id_str': '2759118644',
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'text': "@FleaBagLady @JoodiG @MarewaGlover Well I definitely ain't looking now!",
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Tue Apr 02 10:52:11 +0000 2013',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'Trustee of the charity, New Nicotine Alliance UK @NNAlliance, lettuce expert. \n\nAll opinions expressed are personal.',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'theindefatigablefrog.blogspot.co.uk',
#        'expanded_url': 'http://theindefatigablefrog.blogspot.co.uk/',
#        'indices': [0, 23],
#        'url': 'https://t.co/C205NYyguS'}]}},
#    'favourites_count': 42067,
#    'follow_request_sent': None,
#    'followers_count': 6539,
#    'following': None,
#    'friends_count': 1052,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 1322236688,
#    'id_str': '1322236688',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 174,
#    'location': 'North Cornwall ',
#    'name': 'Lorien Jollye CAO',
#    'notifications': None,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1322236688/1483644078',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/834184977759739904/V0opQGSL_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/834184977759739904/V0opQGSL_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'CaeruleanSea',
#    'statuses_count': 90351,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': 'https://t.co/C205NYyguS',
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Sun Mar 05 23:36:25 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 823668491400126464,
#      'id_str': '823668491400126464',
#      'indices': [0, 11],
#      'name': 'a guy',
#      'screen_name': 'firefly385'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838533689583742976,
#   'id_str': '838533689583742976',
#   'in_reply_to_screen_name': 'firefly385',
#   'in_reply_to_status_id': 838533485908353029,
#   'in_reply_to_status_id_str': '838533485908353029',
#   'in_reply_to_user_id': 823668491400126464,
#   'in_reply_to_user_id_str': '823668491400126464',
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': '@firefly385 you watched it?\n\nNerd.',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sat Mar 08 18:12:02 +0000 2014',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': '#1 Smash Mouth fan, like fr heck off I called dibs.',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 514,
#    'follow_request_sent': None,
#    'followers_count': 60,
#    'following': None,
#    'friends_count': 228,
#    'geo_enabled': False,
#    'has_extended_profile': True,
#    'id': 2379114403,
#    'id_str': '2379114403',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 1,
#    'location': 'Palmyra, PA',
#    'name': 'moral support',
#    'notifications': None,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2379114403/1486957123',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/830984512532336640/KfVOipu9_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/830984512532336640/KfVOipu9_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'aar0nrinehart',
#    'statuses_count': 653,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Sun Mar 05 23:36:24 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 38948372,
#      'id_str': '38948372',
#      'indices': [0, 14],
#      'name': 'Kristen :)',
#      'screen_name': 'ragolznetsirk'},
#     {'id': 62846120,
#      'id_str': '62846120',
#      'indices': [15, 31],
#      'name': 'Hershey Bears',
#      'screen_name': 'TheHersheyBears'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838533685121015808,
#   'id_str': '838533685121015808',
#   'in_reply_to_screen_name': 'ragolznetsirk',
#   'in_reply_to_status_id': 838527666718375936,
#   'in_reply_to_status_id_str': '838527666718375936',
#   'in_reply_to_user_id': 38948372,
#   'in_reply_to_user_id_str': '38948372',
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'text': '@ragolznetsirk @TheHersheyBears Time to put the work boots on in the 3rd Period and make the comeback complete!',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Thu Mar 19 21:28:55 +0000 2009',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Voice of the @TheHersheyBears of the @TheAHL, proud affiliate of @Capitals. Formerly of @SCStingrays & @fightingsaints. @stcloudstate grad. KC native-Go Royals!',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 6227,
#    'follow_request_sent': None,
#    'followers_count': 1950,
#    'following': None,
#    'friends_count': 936,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 25389564,
#    'id_str': '25389564',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 34,
#    'location': 'Hershey, PA',
#    'name': 'Zack Fisch',
#    'notifications': None,
#    'profile_background_color': '9AE4E8',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/378800000018968622/05ada1d2eb9864e0a34db8c97f0603ec.jpeg',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/378800000018968622/05ada1d2eb9864e0a34db8c97f0603ec.jpeg',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/25389564/1483472438',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/819255500277743617/PATBd5cg_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/819255500277743617/PATBd5cg_normal.jpg',
#    'profile_link_color': '5C3317',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': 'DDFFCC',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'zackfisch',
#    'statuses_count': 11931,
#    'time_zone': 'Central Time (US & Canada)',
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': -21600,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Sun Mar 05 23:36:21 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'nationalreview.com/corner/445504/…',
#      'expanded_url': 'http://www.nationalreview.com/corner/445504/obama-camp-disingenuous-denials-fisa-surveillance-trump',
#      'indices': [68, 91],
#      'url': 'https://t.co/7FkLdK0coF'}],
#    'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838533673800589312,
#   'id_str': '838533673800589312',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'text': 'The Obama Camp’s Disingenuous Denials on FISA Surveillance of Trump\nhttps://t.co/7FkLdK0coF',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Thu Apr 09 02:40:37 +0000 2009',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'http://t.co/yI0bYZQf Regular faith-based volunteer. Retired construction project manager and U.S. Air Force veteran. Grt. grandson of Civil War Vet.',
#    'entities': {'description': {'urls': [{'display_url': 'borntopray.wordpress.com',
#        'expanded_url': 'http://borntopray.wordpress.com',
#        'indices': [0, 20],
#        'url': 'http://t.co/yI0bYZQf'}]},
#     'url': {'urls': [{'display_url': 'bitsandbytesofbob.blogspot.com',
#        'expanded_url': 'http://bitsandbytesofbob.blogspot.com',
#        'indices': [0, 22],
#        'url': 'http://t.co/OHOQSNpzjB'}]}},
#    'favourites_count': 286,
#    'follow_request_sent': None,
#    'followers_count': 11055,
#    'following': None,
#    'friends_count': 11525,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 29899648,
#    'id_str': '29899648',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 193,
#    'location': 'York, PA',
#    'name': 'Bob Coches',
#    'notifications': None,
#    'profile_background_color': '8B542B',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme8/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme8/bg.gif',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/29899648/1448148956',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/617312702/Bob_Hat__2_normal.JPG',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/617312702/Bob_Hat__2_normal.JPG',
#    'profile_link_color': '9D582E',
#    'profile_sidebar_border_color': 'D9B17E',
#    'profile_sidebar_fill_color': 'EADEAA',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'ReallyBob',
#    'statuses_count': 11963,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'none',
#    'url': 'http://t.co/OHOQSNpzjB',
#    'utc_offset': -18000,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Sun Mar 05 23:36:18 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'twitter.com/penguins/statu…',
#      'expanded_url': 'https://twitter.com/penguins/status/838518847426658305',
#      'indices': [58, 81],
#      'url': 'https://t.co/1PxeEPTOIh'}],
#    'user_mentions': [{'id': 1413842822,
#      'id_str': '1413842822',
#      'indices': [33, 46],
#      'name': 'Hayden Bankes',
#      'screen_name': 'HaydenBankes'},
#     {'id': 4217196977,
#      'id_str': '4217196977',
#      'indices': [47, 57],
#      'name': 'ADRAGNA STARE',
#      'screen_name': 'MattStare'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838533662035623936,
#   'id_str': '838533662035623936',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': True,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'quoted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Sun Mar 05 22:37:26 +0000 2017',
#    'entities': {'hashtags': [],
#     'media': [{'display_url': 'pic.twitter.com/WV3tgYMMLT',
#       'expanded_url': 'https://twitter.com/penguins/status/838518847426658305/photo/1',
#       'id': 838518705151692802,
#       'id_str': '838518705151692802',
#       'indices': [53, 76],
#       'media_url': 'http://pbs.twimg.com/media/C6MEUdYWUAIPYQ0.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/C6MEUdYWUAIPYQ0.jpg',
#       'sizes': {'large': {'h': 750, 'resize': 'fit', 'w': 1330},
#        'medium': {'h': 677, 'resize': 'fit', 'w': 1200},
#        'small': {'h': 383, 'resize': 'fit', 'w': 680},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/WV3tgYMMLT'}],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': []},
#    'extended_entities': {'media': [{'display_url': 'pic.twitter.com/WV3tgYMMLT',
#       'expanded_url': 'https://twitter.com/penguins/status/838518847426658305/photo/1',
#       'id': 838518705151692802,
#       'id_str': '838518705151692802',
#       'indices': [53, 76],
#       'media_url': 'http://pbs.twimg.com/media/C6MEUdYWUAIPYQ0.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/C6MEUdYWUAIPYQ0.jpg',
#       'sizes': {'large': {'h': 750, 'resize': 'fit', 'w': 1330},
#        'medium': {'h': 677, 'resize': 'fit', 'w': 1200},
#        'small': {'h': 383, 'resize': 'fit', 'w': 680},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/WV3tgYMMLT'}]},
#    'favorite_count': 1019,
#    'favorited': False,
#    'geo': None,
#    'id': 838518847426658305,
#    'id_str': '838518847426658305',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 524,
#    'retweeted': False,
#    'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#    'text': "We're just going to leave this here for reference. 👀 https://t.co/WV3tgYMMLT",
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Thu Jun 05 17:36:02 +0000 2008',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'The Official Twitter Home of the NHL’s Pittsburgh Penguins. Join the conversation using #Pens | https://t.co/p85GH8kmHM',
#     'entities': {'description': {'urls': [{'display_url': 'instagram.com/penguins',
#         'expanded_url': 'http://www.instagram.com/penguins',
#         'indices': [96, 119],
#         'url': 'https://t.co/p85GH8kmHM'}]},
#      'url': {'urls': [{'display_url': 'pittsburghpenguins.com',
#         'expanded_url': 'http://www.pittsburghpenguins.com',
#         'indices': [0, 23],
#         'url': 'https://t.co/Q7FokXFGPf'}]}},
#     'favourites_count': 16868,
#     'follow_request_sent': None,
#     'followers_count': 1241734,
#     'following': None,
#     'friends_count': 174,
#     'geo_enabled': True,
#     'has_extended_profile': False,
#     'id': 15020865,
#     'id_str': '15020865',
#     'is_translation_enabled': True,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 7207,
#     'location': 'Pittsburgh, PA',
#     'name': 'Pittsburgh Penguins',
#     'notifications': None,
#     'profile_background_color': '23282B',
#     'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/888702049/8b96c4aae915713334d1173457bef877.jpeg',
#     'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/888702049/8b96c4aae915713334d1173457bef877.jpeg',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/15020865/1488573346',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/835144106749865985/NNIjPvHW_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/835144106749865985/NNIjPvHW_normal.jpg',
#     'profile_link_color': 'FDBB30',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': 'D3C89D',
#     'profile_text_color': '212121',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'penguins',
#     'statuses_count': 71250,
#     'time_zone': 'Eastern Time (US & Canada)',
#     'translator_type': 'none',
#     'url': 'https://t.co/Q7FokXFGPf',
#     'utc_offset': -18000,
#     'verified': True}},
#   'quoted_status_id': 838518847426658305,
#   'quoted_status_id_str': '838518847426658305',
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'text': "And they said we didn't score??? @HaydenBankes @MattStare https://t.co/1PxeEPTOIh",
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sat Mar 04 18:22:24 +0000 2017',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'RLHS, Class of 2018, RL Basketball, Football, Fishing, Hunting, Ping Pong, BLEEDS BLACK AND YELLOW, BLEEDS TERPS RED, ROMANS 1:16 For Life #BragOnMyLordnCreator',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 76,
#    'follow_request_sent': None,
#    'followers_count': 28,
#    'following': None,
#    'friends_count': 220,
#    'geo_enabled': False,
#    'has_extended_profile': True,
#    'id': 838092278086451201,
#    'id_str': '838092278086451201',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 0,
#    'location': 'Lewisberry, PA',
#    'name': 'Matthew Seiferth',
#    'notifications': None,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/838092278086451201/1488678649',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/838198701285756929/xXyewq7-_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/838198701285756929/xXyewq7-_normal.jpg',
#    'profile_link_color': 'ABB8C2',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'protected': False,
#    'screen_name': 'SeifDaddy4399',
#    'statuses_count': 49,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Sun Mar 05 23:36:10 +0000 2017',
#   'entities': {'hashtags': [{'indices': [53, 57], 'text': 'hbh'},
#     {'indices': [58, 71], 'text': 'DefendTheDen'}],
#    'media': [{'display_url': 'pic.twitter.com/8NoshCzOu7',
#      'expanded_url': 'https://twitter.com/TheHersheyBears/status/838533625406767108/photo/1',
#      'id': 838533617005527040,
#      'id_str': '838533617005527040',
#      'indices': [72, 95],
#      'media_url': 'http://pbs.twimg.com/media/C6MR4cXWgAAh5Cb.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/C6MR4cXWgAAh5Cb.jpg',
#      'sizes': {'large': {'h': 1536, 'resize': 'fit', 'w': 2048},
#       'medium': {'h': 900, 'resize': 'fit', 'w': 1200},
#       'small': {'h': 510, 'resize': 'fit', 'w': 680},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'type': 'photo',
#      'url': 'https://t.co/8NoshCzOu7'}],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': []},
#   'extended_entities': {'media': [{'display_url': 'pic.twitter.com/8NoshCzOu7',
#      'expanded_url': 'https://twitter.com/TheHersheyBears/status/838533625406767108/photo/1',
#      'id': 838533617005527040,
#      'id_str': '838533617005527040',
#      'indices': [72, 95],
#      'media_url': 'http://pbs.twimg.com/media/C6MR4cXWgAAh5Cb.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/C6MR4cXWgAAh5Cb.jpg',
#      'sizes': {'large': {'h': 1536, 'resize': 'fit', 'w': 2048},
#       'medium': {'h': 900, 'resize': 'fit', 'w': 1200},
#       'small': {'h': 510, 'resize': 'fit', 'w': 680},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'type': 'photo',
#      'url': 'https://t.co/8NoshCzOu7'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838533625406767108,
#   'id_str': '838533625406767108',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': {'attributes': {},
#    'bounding_box': {'coordinates': [[[-76.6691529750824, 40.286417106644954],
#       [-76.6691529750824, 40.286417106644954],
#       [-76.6691529750824, 40.286417106644954],
#       [-76.6691529750824, 40.286417106644954]]],
#     'type': 'Polygon'},
#    'contained_within': [],
#    'country': 'United States',
#    'country_code': 'US',
#    'full_name': 'Giant Center',
#    'id': '07d9f5ba0f084005',
#    'name': 'Giant Center',
#    'place_type': 'poi',
#    'url': 'https://api.twitter.com/1.1/geo/id/07d9f5ba0f084005.json'},
#   'possibly_sensitive': False,
#   'retweet_count': 1,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': 'Thank you to everyone who came out for Mascot Mania! #hbh #DefendTheDen https://t.co/8NoshCzOu7',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Tue Aug 04 15:30:54 +0000 2009',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'The Official Twitter page of the Hershey Bears. Dedicated to news, photos and all things Hershey Bears. Follow us on 👻: hersheybears38',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'HersheyBears.com',
#        'expanded_url': 'http://HersheyBears.com',
#        'indices': [0, 23],
#        'url': 'https://t.co/HZRnnx2eBU'}]}},
#    'favourites_count': 1693,
#    'follow_request_sent': None,
#    'followers_count': 45053,
#    'following': None,
#    'friends_count': 73,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 62846120,
#    'id_str': '62846120',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 623,
#    'location': 'Hershey',
#    'name': 'Hershey Bears',
#    'notifications': None,
#    'profile_background_color': 'E0A54C',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/458230800337469441/nG9rPRth.jpeg',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/458230800337469441/nG9rPRth.jpeg',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/62846120/1477326093',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/741972706367819777/NyR-jRRf_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/741972706367819777/NyR-jRRf_normal.jpg',
#    'profile_link_color': '94091E',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'F3F3F3',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'TheHersheyBears',
#    'statuses_count': 14637,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'none',
#    'url': 'https://t.co/HZRnnx2eBU',
#    'utc_offset': -18000,
#    'verified': True}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Sun Mar 05 23:35:57 +0000 2017',
#   'entities': {'hashtags': [], 'symbols': [], 'urls': [], 'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838533572164206593,
#   'id_str': '838533572164206593',
#   'in_reply_to_screen_name': 'NoahFenceMendes',
#   'in_reply_to_status_id': 838533075910934529,
#   'in_reply_to_status_id_str': '838533075910934529',
#   'in_reply_to_user_id': 2357518183,
#   'in_reply_to_user_id_str': '2357518183',
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': '.  Soon the vehicle starts driving backwards in circles, faster and faster as a light (it was getting dark outside) from another car was',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sun Feb 23 05:47:06 +0000 2014',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'YouTubers, Music Artists and Drag Queens are my life!!! Follow back account: @GagaMendesDoww!',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'YOUTUBE.COM/WHATPEOPLEMISS',
#        'expanded_url': 'http://YOUTUBE.COM/WHATPEOPLEMISS',
#        'indices': [0, 23],
#        'url': 'https://t.co/oDvPXbgRc4'}]}},
#    'favourites_count': 157342,
#    'follow_request_sent': None,
#    'followers_count': 6609,
#    'following': None,
#    'friends_count': 2334,
#    'geo_enabled': True,
#    'has_extended_profile': True,
#    'id': 2357518183,
#    'id_str': '2357518183',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 43,
#    'location': 'Mount Joy, PA',
#    'name': 'Matt',
#    'notifications': None,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/515585259992150016/MH4wCYUz.png',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/515585259992150016/MH4wCYUz.png',
#    'profile_background_tile': True,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2357518183/1486475701',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/834621038663065600/JlZRS9KE_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/834621038663065600/JlZRS9KE_normal.jpg',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'NoahFenceMendes',
#    'statuses_count': 90516,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'none',
#    'url': 'https://t.co/oDvPXbgRc4',
#    'utc_offset': -18000,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Sun Mar 05 23:35:53 +0000 2017',
#   'entities': {'hashtags': [], 'symbols': [], 'urls': [], 'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838533556557201408,
#   'id_str': '838533556557201408',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'text': "Enough with changing the rules of baseball. Half of the comments that I've read are just plain stupid.",
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Thu Oct 13 00:17:45 +0000 2011',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'I love my Ravens, Orioles, Capitals and Penn State!',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 8263,
#    'follow_request_sent': None,
#    'followers_count': 871,
#    'following': None,
#    'friends_count': 2289,
#    'geo_enabled': True,
#    'has_extended_profile': True,
#    'id': 389785574,
#    'id_str': '389785574',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 5,
#    'location': 'Dover, Pa\n',
#    'name': 'RavensNation',
#    'notifications': None,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/389785574/1456250554',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/756809161539584001/y7aWHVR-_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/756809161539584001/y7aWHVR-_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'MFrazier1998',
#    'statuses_count': 16533,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Sun Mar 05 23:35:52 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'twitter.com/i/web/status/8…',
#      'expanded_url': 'https://twitter.com/i/web/status/838533552882999297',
#      'indices': [117, 140],
#      'url': 'https://t.co/iven0oKwGC'}],
#    'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838533552882999297,
#   'id_str': '838533552882999297',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': True,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'quoted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Sun Mar 05 03:20:04 +0000 2017',
#    'entities': {'hashtags': [{'indices': [0, 9], 'text': 'Democrat'},
#      {'indices': [36, 42], 'text': 'Obama'},
#      {'indices': [55, 67], 'text': 'Wiretapping'},
#      {'indices': [84, 97], 'text': 'lorettalynch'}],
#     'symbols': [],
#     'urls': [{'display_url': 'twitter.com/i/web/status/8…',
#       'expanded_url': 'https://twitter.com/i/web/status/838227586060812288',
#       'indices': [107, 130],
#       'url': 'https://t.co/82oQ4C9IaQ'}],
#     'user_mentions': []},
#    'favorite_count': 935,
#    'favorited': False,
#    'geo': None,
#    'id': 838227586060812288,
#    'id_str': '838227586060812288',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 1036,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'text': '#Democrat Style👉Always Blame Others!#Obama Doesnt Deny #Wiretapping,Diverts Blame 2 #lorettalynch His DOJ… https://t.co/82oQ4C9IaQ',
#    'truncated': True,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Sat Aug 21 18:08:51 +0000 2010',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': "WELCOME! ITS MY HONOR TO STAND WITH #PresidentTrump @POTUS & ALL BRAVE GREAT PATRIOTS ! WE'RE GOING TO TAKE OUR COUNTRY BACK ! GOD BLESS US ALL ! #MAGA",
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'mcaf.ee/o8ulm0?ANOMALY1',
#         'expanded_url': 'http://mcaf.ee/o8ulm0?ANOMALY1',
#         'indices': [0, 23],
#         'url': 'https://t.co/dIkF78BYmv'}]}},
#     'favourites_count': 78524,
#     'follow_request_sent': None,
#     'followers_count': 34975,
#     'following': None,
#     'friends_count': 15577,
#     'geo_enabled': False,
#     'has_extended_profile': True,
#     'id': 181249422,
#     'id_str': '181249422',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 185,
#     'location': 'AMERICA FIRST!',
#     'name': 'TRUMP ANOMALY®',
#     'notifications': None,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme18/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme18/bg.gif',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/181249422/1471394291',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/835607558140407808/7fM8xwzf_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/835607558140407808/7fM8xwzf_normal.jpg',
#     'profile_link_color': '1B95E0',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'protected': False,
#     'screen_name': 'ANOMALY1',
#     'statuses_count': 37544,
#     'time_zone': 'Pacific Time (US & Canada)',
#     'translator_type': 'regular',
#     'url': 'https://t.co/dIkF78BYmv',
#     'utc_offset': -28800,
#     'verified': False}},
#   'quoted_status_id': 838227586060812288,
#   'quoted_status_id_str': '838227586060812288',
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>',
#   'text': "They're shady she meets with Clinton he plants information for senate Dems order to frame our POTUS they are totall… https://t.co/iven0oKwGC",
#   'truncated': True,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sat Jan 21 13:05:53 +0000 2017',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'Average all American woman 49 Mother of 1 female 1 male 3 dogs married pro choice atheist republican 1/2 Puerto Rican 1/2 Irish',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 1951,
#    'follow_request_sent': None,
#    'followers_count': 99,
#    'following': None,
#    'friends_count': 176,
#    'geo_enabled': False,
#    'has_extended_profile': True,
#    'id': 822792330289745920,
#    'id_str': '822792330289745920',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 7,
#    'location': 'Camp Hill, PA',
#    'name': 'Angela allander',
#    'notifications': None,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/822880462121136128/dUV1CtzP_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/822880462121136128/dUV1CtzP_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'AngelaAllander',
#    'statuses_count': 5309,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Sun Mar 05 23:35:49 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 805818994255167488,
#      'id_str': '805818994255167488',
#      'indices': [3, 18],
#      'name': 'Chris Battistelli',
#      'screen_name': 'Battistelli814'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838533536927866880,
#   'id_str': '838533536927866880',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 3,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Sun Mar 05 20:14:02 +0000 2017',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': []},
#    'favorite_count': 5,
#    'favorited': False,
#    'geo': None,
#    'id': 838482760230703104,
#    'id_str': '838482760230703104',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 3,
#    'retweeted': False,
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Mobile Web (M5)</a>',
#    'text': 'NL vs Dobbins at Lebanon high 5:00 Friday!',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Mon Dec 05 16:59:54 +0000 2016',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': '',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 53,
#     'follow_request_sent': None,
#     'followers_count': 18,
#     'following': None,
#     'friends_count': 61,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 805818994255167488,
#     'id_str': '805818994255167488',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 0,
#     'location': 'Lebanon, PA',
#     'name': 'Chris Battistelli',
#     'notifications': None,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/805830096556847105/uOqRSmOl_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/805830096556847105/uOqRSmOl_normal.jpg',
#     'profile_link_color': '0084B4',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'protected': False,
#     'screen_name': 'Battistelli814',
#     'statuses_count': 17,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': None,
#     'verified': False}},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': 'RT @Battistelli814: NL vs Dobbins at Lebanon high 5:00 Friday!',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Tue Sep 10 02:32:24 +0000 2013',
#    'default_profile': True,
#    'default_profile_image': True,
#    'description': '',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 59,
#    'follow_request_sent': None,
#    'followers_count': 18,
#    'following': None,
#    'friends_count': 50,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 1850108162,
#    'id_str': '1850108162',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 0,
#    'location': '',
#    'name': 'lori brandt',
#    'notifications': None,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_0_normal.png',
#    'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_0_normal.png',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'brandt_lori',
#    'statuses_count': 33,
#    'time_zone': 'Pacific Time (US & Canada)',
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': -28800,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Sun Mar 05 23:35:45 +0000 2017',
#   'entities': {'hashtags': [], 'symbols': [], 'urls': [], 'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838533522444922881,
#   'id_str': '838533522444922881',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': "I wanna go through my clothes and get rid of stuff I don't wear, buttttt I can't afford to replace the old stuff 😅",
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sun Mar 25 22:58:52 +0000 2012',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': "Penn State Mont Alto '20• 06/23/2016•",
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 2707,
#    'follow_request_sent': None,
#    'followers_count': 439,
#    'following': None,
#    'friends_count': 242,
#    'geo_enabled': True,
#    'has_extended_profile': True,
#    'id': 536717377,
#    'id_str': '536717377',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 1,
#    'location': 'Carlisle, PA',
#    'name': 'Olivia Hippensteel',
#    'notifications': None,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/536717377/1487230611',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/832131602406858752/Eli8OwxQ_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/832131602406858752/Eli8OwxQ_normal.jpg',
#    'profile_link_color': 'E81C4F',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'protected': False,
#    'screen_name': 'oliviacole03',
#    'statuses_count': 8098,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Sun Mar 05 23:35:45 +0000 2017',
#   'entities': {'hashtags': [], 'symbols': [], 'urls': [], 'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838533520918200321,
#   'id_str': '838533520918200321',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': 'sooooo are we skipping tomorrow or is that not a thing ?',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Wed Jan 28 01:36:10 +0000 2015',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'IG: sarajordaan14 // SNAP: sarjord17 // doin well.',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 7343,
#    'follow_request_sent': None,
#    'followers_count': 670,
#    'following': None,
#    'friends_count': 549,
#    'geo_enabled': True,
#    'has_extended_profile': True,
#    'id': 3002454569,
#    'id_str': '3002454569',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 1,
#    'location': 'York, PA',
#    'name': 'sara jordan',
#    'notifications': None,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3002454569/1487431704',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/829346853112143872/5TeGQqAm_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/829346853112143872/5TeGQqAm_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'SaraJordaan14',
#    'statuses_count': 10684,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': -18000,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Sun Mar 05 23:35:43 +0000 2017',
#   'entities': {'hashtags': [], 'symbols': [], 'urls': [], 'user_mentions': []},
#   'favorite_count': 1,
#   'favorited': False,
#   'geo': None,
#   'id': 838533515209760768,
#   'id_str': '838533515209760768',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': 'She literally fucking calls people nigg**s',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sun Feb 13 17:17:14 +0000 2011',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'BLM BTLM',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'Instagram.com/bvxjt',
#        'expanded_url': 'http://Instagram.com/bvxjt',
#        'indices': [0, 23],
#        'url': 'https://t.co/hGkZm6J1ru'}]}},
#    'favourites_count': 23586,
#    'follow_request_sent': None,
#    'followers_count': 2160,
#    'following': None,
#    'friends_count': 962,
#    'geo_enabled': False,
#    'has_extended_profile': True,
#    'id': 251690866,
#    'id_str': '251690866',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 15,
#    'location': 'Paxtonia, PA',
#    'name': 'jordan',
#    'notifications': None,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/378800000090937546/564fa1d96203c49adaaa2d9e76c83259.jpeg',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/378800000090937546/564fa1d96203c49adaaa2d9e76c83259.jpeg',
#    'profile_background_tile': True,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/251690866/1487835988',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/837859432952385537/3lRSJihY_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/837859432952385537/3lRSJihY_normal.jpg',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '7AC3EE',
#    'profile_text_color': '000000',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'fxcjt',
#    'statuses_count': 105671,
#    'time_zone': 'Quito',
#    'translator_type': 'regular',
#    'url': 'https://t.co/hGkZm6J1ru',
#    'utc_offset': -18000,
#    'verified': False}}]

# %% [markdown]
# ### 4. Automate it - Hit the API and Parse the Result
#
# We are going to create a function to help us repeatedly hit the API, and parse the result into a readable JSON that contains the things that we are interested in, and still stores the raw tweet as an additional property. The returned object is a Python `dict` that we can easily parse into another dictionary to later store as a JSON. Raw JSONs returned from the API have a specific structure.
#
# It can be sometimes hard to read a raw JSON. I find it easy to use some online parsers like [this]( http://jsonparseronline.com/) to look at the structure of the JSON, and only access what we care about.
#
# Note: Remember we are limited to 450 every 15 minutes.

# %%
# Does pretty much what its long name suggests.
def get_lots_of_tweets( latlong ):
    # Create a dictionary to parse the JSON
    all_tweets = {}
    
    # We will be hitting the API a number of times within the total time
    total_time = 10
    
    # Everytime we hit the API we subtract time from the total
    remaining_seconds = total_time
    interval = 5
    while remaining_seconds > 0: # loop and run the function while remaining seconds is greater than zero
        added = 0
        # Hit the Twitter API using our function
        new_tweets = get_tweets_by_location(latlong) # we set latlong above!
        # Parse the resulting JSON, and save the rest of the raw content
        for tweet in new_tweets:
            tid = tweet['id']
            if tid not in all_tweets:
                properties = {}
                if tweet['coordinates'] != None:
                    properties['lat'] = tweet['coordinates']['coordinates'][0]
                    properties['lon'] = tweet['coordinates']['coordinates'][1]
                else:
                    properties['lat'] = None
                    properties['lon'] = None
                properties['location'] = tweet['user']['location'] #This will get us the location associated with the profile
                properties['tweet_id'] = tid
                properties['content'] = tweet['text']
                properties['user'] = tweet['user']['id']
                properties['raw_source'] = tweet
                properties['data_point'] = 'none'
                properties['time'] = tweet['created_at']
                all_tweets[ tid ] = properties
                added += 1
        print("At %d seconds, added %d new tweets, for a total of %d" % ( total_time - remaining_seconds, added, len( all_tweets )))
        # We wait a few seconds and hit the API again
        time.sleep(interval)
        remaining_seconds -= interval
    print(str(len(all_tweets)) + ' Tweets retrieved.')
    # We return the final dictionary to work with in Python
    return all_tweets

# %% [markdown]
# ### 5. Run the Twitter Scraper
#
# We need to call the functions, and save the JSONs into a location. In this case, I made a folder called **data**, where I am saving all the new JSONS. We can run the code continuously utilizing some loop, or we can use libraries like [threading](https://docs.python.org/3.6/library/threading.html).
#
# *Make sure you have a folder named **data** in the directory with your notebook! This function will save our collected datafiles to it when it finishes running.*

# %%
# This function executes the the functions over a given period of time
def run_all():
    # This is the number of times the code will be executed. In this case, just once. 
    starting = 1
    while starting > 0:
        # Sometimes the API returns some errors, killing the whole script, so we setup try/except to make sure it keeps running
        try:
            t = get_lots_of_tweets( latlong )
            # We name every file with the current time
            timestr = time.strftime("%Y%m%d-%H%M%S")
            # We write a new JSON into the target path
            with open( 'data/' + '%stweets.json' %(timestr), 'w' ) as f:
                f.write(json.dumps(t))
            # we can use a library like threading to execute the run function continuously.
            #threading.Timer(10, run).start()
            starting -= 1
        except:
            pass
    
run_all()
# Out:
# At 0 seconds, added 15 new tweets, for a total of 15
# At 5 seconds, added 0 new tweets, for a total of 15
# 15 Tweets retrieved.

# %% [markdown]
# ### 6. Let's Explore the Data we Saved to our Machine
#
# Let's look through the JSON we created and checkout some of the data we just downloaded. First, let's import a couple of additional libraries that will let us interact with our file system, use numpy and pandas, and create plots:

# %%
# Import some additional libraries that will allow us to plot and interact with the operating system
from os import listdir
from os.path import isfile, join
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Next, let's explore our data a bit. This following function will allow us to perform a visual examination of what we downloaded from Twitter. Once we have collected some data, we can parse it, and visualize some of the results. Since some of the data is repeated, we can initialize some lists to check whether or not a tweet already exists, and add it to the list. We can then extract the useful information for our purposes, and store it in another list.
#
# Building on last week, we can do this in Pandas.

# %%
# Get the file names from a given directory
file_dir = "data" # Set this to where your JSON saved
# Get only the JSONs we have saved
onlyfiles = [ f for f in listdir(file_dir) if isfile(join(file_dir,f)) and not f.startswith('.')]

# create an empty dataframe with columns for each property
df_tweets = pd.DataFrame(columns = ['tweet_id', 'lat', 'lon', 'content','location','user','raw_source','data_point','time'])

# Loop through all the files
for file in onlyfiles:
    full_dir = join(file_dir,file) 
    with open(full_dir) as json_data:
        dict = json.load(json_data) # creates a Python dictionary of our json
        if not isinstance(dict, list):
            for key, val in dict.items():
                df_tweets.loc[key,val] = val
                
df_tweets
# Out:
#                               tweet_id      lat      lon  \
# 836964415278718977  836964415278718977     None     None
# 836964383427284994  836964383427284994     None     None
# 836964370676596736  836964370676596736     None     None
# 836964370508824576  836964370508824576     None     None
# 836964361717628930  836964361717628930     None     None
# 836964342289543168  836964342289543168     None     None
# 836964334005862400  836964334005862400     None     None
# 836964333192097792  836964333192097792     None     None
# 836964328653778944  836964328653778944     None     None
# 836964328620322816  836964328620322816     None     None
# 836964328360267776  836964328360267776     None     None
# 836964312275116032  836964312275116032     None     None
# 836964311562088448  836964311562088448     None     None
# 836964303773237248  836964303773237248     None     None
# 836964301709664256  836964301709664256     None     None
# 838533971575246850  838533971575246850     None     None
# 838533956991660033  838533956991660033     None     None
# 838533954714144768  838533954714144768     None     None
# 838533954139480064  838533954139480064 -76.8433   40.261
# 838533945801191430  838533945801191430     None     None
# 838533929418248192  838533929418248192     None     None
# 838533917405761536  838533917405761536     None     None
# 838533891992477696  838533891992477696 -76.5624  40.0559
# 838533888473509889  838533888473509889     None     None
# 838533873097125888  838533873097125888     None     None
# 838533864243007488  838533864243007488     None     None
# 838533845075046401  838533845075046401     None     None
# 838533824724205568  838533824724205568     None     None
# 838533821863706625  838533821863706625     None     None
# 838533773448757248  838533773448757248 -76.6512  40.2784
#
#                                                               content  \
# 836964415278718977  RT @realJeffreyLord: Trump critic Van Jones: ‘...
# 836964383427284994  WEATHER ALERT: A Severe Storm WATCH in effect ...
# 836964370676596736  RT @PADeptofEd: “My budget puts kids first” ➡️...
# 836964370508824576  Personalizing educator professional developmen...
# 836964361717628930  RT @realJeffreyLord: Yes. Exactly. https://t.c...
# 836964342289543168  #CarMaintenance Tips for the First Time E-Car ...
# 836964334005862400  How?? It's our fault for paying her or even co...
# 836964333192097792  Are you prepared if a severe storm strikes in ...
# 836964328653778944              RT @debasesu: https://t.co/e9RJmruzjZ
# 836964328620322816  @sydneifryson Check out some of our favorite #...
# 836964328360267776  @TymothyLongoria @acthomasbooks @ShelfAwarenes...
# 836964312275116032  I posted a new photo to Facebook https://t.co/...
# 836964311562088448  RT @We_Are_Penn_St: @FoxNews @POTUS @DeptofDef...
# 836964303773237248  This is why personalized PD is relevant. #macp...
# 836964301709664256  @travlingtheroad @marcuslemonis where was the ...
# 838533971575246850  My level of pettiness toward RM extends to FEU...
# 838533956991660033  getting lighter and lighter.  Then the seat in...
# 838533954714144768  A little #Throwback: How To Start Seeds In Egg...
# 838533954139480064  Whoa! Glad I'm having smoked steak! This need....
# 838533945801191430  @tessav87 It's OK, Tess! :) You're also very s...
# 838533929418248192         RT @msannyy: X2 🍭✨ https://t.co/a2WdEPhH83
# 838533917405761536  When you hate homework😒 but don't wanna fail  ...
# 838533891992477696  #bigmuddybrewing #galaxy #ipa #nicksbistro #ma...
# 838533888473509889            The hill is now closed for the evening.
# 838533873097125888  Here's another "Outfit of the Day"\n(XXS) Carl...
# 838533864243007488  The “moral test” facing Los Angeles over depor...
# 838533845075046401  If Trump doesn't stop "crying wolf"with ridicu...
# 838533824724205568  Internally screaming at work right now. Yas qu...
# 838533821863706625  Israel marijuana: Users to face fine rather th...
# 838533773448757248  all smiles when I'm with my bff💗 @ Hershey, Pe...
#
#                                location                user  \
# 836964415278718977    Newport Beach, CA            20730083
# 836964383427284994       Harrisburg, PA          2473829791
# 836964370676596736     Philadelphia, PA          3631050620
# 836964370508824576    Mechanicsburg, PA  835912294731239424
# 836964361717628930                 OHIO           247036262
# 836964342289543168         Carlisle, PA          3252470211
# 836964334005862400       Harrisburg, PA           245175488
# 836964333192097792       Harrisburg, PA          3218464527
# 836964328653778944             Mesa, AZ          2191808276
# 836964328620322816       Harrisburg, PA  836244015490056192
# 836964328360267776        Highspire, PA           127707068
# 836964312275116032        Jonestown, PA          2290345160
# 836964311562088448  Bay, Gulf of Mexico          2952557518
# 836964303773237248          Manheim, PA          4097398883
# 836964301709664256         Hershey, PA           2584490635
# 838533971575246850     Wrightsville, PA           311219239
# 838533956991660033        Mount Joy, PA          2357518183
# 838533954714144768             York, PA            21632854
# 838533954139480064      Linglestown, PA          2423758021
# 838533945801191430        Grantville,PA          1873757142
# 838533929418248192                       694694887409647618
# 838533917405761536      Harrisburg , PA          2970479398
# 838533891992477696         Marietta, PA           387974372
# 838533888473509889          Lebanon, Pa          4359999974
# 838533873097125888             York, PA  813570323681570817
# 838533864243007488           Harrisburg           741384337
# 838533845075046401                                252098575
# 838533824724205568    Elizabethtown, Pa           526798667
# 838533821863706625    Elizabethtown, PA           373073651
# 838533773448757248                   PA           615275045
#
#                                                            raw_source  \
# 836964415278718977  {'created_at': 'Wed Mar 01 15:40:41 +0000 2017...
# 836964383427284994  {'created_at': 'Wed Mar 01 15:40:33 +0000 2017...
# 836964370676596736  {'created_at': 'Wed Mar 01 15:40:30 +0000 2017...
# 836964370508824576  {'created_at': 'Wed Mar 01 15:40:30 +0000 2017...
# 836964361717628930  {'created_at': 'Wed Mar 01 15:40:28 +0000 2017...
# 836964342289543168  {'created_at': 'Wed Mar 01 15:40:23 +0000 2017...
# 836964334005862400  {'created_at': 'Wed Mar 01 15:40:21 +0000 2017...
# 836964333192097792  {'created_at': 'Wed Mar 01 15:40:21 +0000 2017...
# 836964328653778944  {'created_at': 'Wed Mar 01 15:40:20 +0000 2017...
# 836964328620322816  {'created_at': 'Wed Mar 01 15:40:20 +0000 2017...
# 836964328360267776  {'created_at': 'Wed Mar 01 15:40:20 +0000 2017...
# 836964312275116032  {'created_at': 'Wed Mar 01 15:40:16 +0000 2017...
# 836964311562088448  {'created_at': 'Wed Mar 01 15:40:16 +0000 2017...
# 836964303773237248  {'created_at': 'Wed Mar 01 15:40:14 +0000 2017...
# 836964301709664256  {'created_at': 'Wed Mar 01 15:40:14 +0000 2017...
# 838533971575246850  {'created_at': 'Sun Mar 05 23:37:32 +0000 2017...
# 838533956991660033  {'created_at': 'Sun Mar 05 23:37:29 +0000 2017...
# 838533954714144768  {'created_at': 'Sun Mar 05 23:37:28 +0000 2017...
# 838533954139480064  {'created_at': 'Sun Mar 05 23:37:28 +0000 2017...
# 838533945801191430  {'created_at': 'Sun Mar 05 23:37:26 +0000 2017...
# 838533929418248192  {'created_at': 'Sun Mar 05 23:37:22 +0000 2017...
# 838533917405761536  {'created_at': 'Sun Mar 05 23:37:19 +0000 2017...
# 838533891992477696  {'created_at': 'Sun Mar 05 23:37:13 +0000 2017...
# 838533888473509889  {'created_at': 'Sun Mar 05 23:37:12 +0000 2017...
# 838533873097125888  {'created_at': 'Sun Mar 05 23:37:09 +0000 2017...
# 838533864243007488  {'created_at': 'Sun Mar 05 23:37:07 +0000 2017...
# 838533845075046401  {'created_at': 'Sun Mar 05 23:37:02 +0000 2017...
# 838533824724205568  {'created_at': 'Sun Mar 05 23:36:57 +0000 2017...
# 838533821863706625  {'created_at': 'Sun Mar 05 23:36:56 +0000 2017...
# 838533773448757248  {'created_at': 'Sun Mar 05 23:36:45 +0000 2017...
#
#                    data_point                            time
# 836964415278718977       none  Wed Mar 01 15:40:41 +0000 2017
# 836964383427284994       none  Wed Mar 01 15:40:33 +0000 2017
# 836964370676596736       none  Wed Mar 01 15:40:30 +0000 2017
# 836964370508824576       none  Wed Mar 01 15:40:30 +0000 2017
# 836964361717628930       none  Wed Mar 01 15:40:28 +0000 2017
# 836964342289543168       none  Wed Mar 01 15:40:23 +0000 2017
# 836964334005862400       none  Wed Mar 01 15:40:21 +0000 2017
# 836964333192097792       none  Wed Mar 01 15:40:21 +0000 2017
# 836964328653778944       none  Wed Mar 01 15:40:20 +0000 2017
# 836964328620322816       none  Wed Mar 01 15:40:20 +0000 2017
# 836964328360267776       none  Wed Mar 01 15:40:20 +0000 2017
# 836964312275116032       none  Wed Mar 01 15:40:16 +0000 2017
# 836964311562088448       none  Wed Mar 01 15:40:16 +0000 2017
# 836964303773237248       none  Wed Mar 01 15:40:14 +0000 2017
# 836964301709664256       none  Wed Mar 01 15:40:14 +0000 2017
# 838533971575246850       none  Sun Mar 05 23:37:32 +0000 2017
# 838533956991660033       none  Sun Mar 05 23:37:29 +0000 2017
# 838533954714144768       none  Sun Mar 05 23:37:28 +0000 2017
# 838533954139480064       none  Sun Mar 05 23:37:28 +0000 2017
# 838533945801191430       none  Sun Mar 05 23:37:26 +0000 2017
# 838533929418248192       none  Sun Mar 05 23:37:22 +0000 2017
# 838533917405761536       none  Sun Mar 05 23:37:19 +0000 2017
# 838533891992477696       none  Sun Mar 05 23:37:13 +0000 2017
# 838533888473509889       none  Sun Mar 05 23:37:12 +0000 2017
# 838533873097125888       none  Sun Mar 05 23:37:09 +0000 2017
# 838533864243007488       none  Sun Mar 05 23:37:07 +0000 2017
# 838533845075046401       none  Sun Mar 05 23:37:02 +0000 2017
# 838533824724205568       none  Sun Mar 05 23:36:57 +0000 2017
# 838533821863706625       none  Sun Mar 05 23:36:56 +0000 2017
# 838533773448757248       none  Sun Mar 05 23:36:45 +0000 2017

# %% [markdown]
# ### 7. Summarize, Group, and Plot the Dataset
#
# Next let's summarize and group our data, and create some plots.
#
# **A** - First, group by the user location. This is not lat/lon, but rather the information the individual has input on their profile.
#
# When you give people the power to input their own location, you get an assortment of 'creative' responses!

# %%
df_tweets.dtypes
# Out:
# tweet_id      object
# lat           object
# lon           object
# content       object
# location      object
# user          object
# raw_source    object
# data_point    object
# time          object
# dtype: object

# %%
df_tweets['location'].unique()
# Out:
# array(['Newport Beach, CA', 'Harrisburg, PA', 'Philadelphia, PA',
#        'Mechanicsburg, PA', 'OHIO', 'Carlisle, PA', 'Mesa, AZ',
#        'Highspire, PA', 'Jonestown, PA', 'Bay, Gulf of Mexico',
#        'Manheim, PA', 'Hershey, PA ', 'Wrightsville, PA', 'Mount Joy, PA',
#        'York, PA', 'Linglestown, PA', 'Grantville,PA', '',
#        'Harrisburg , PA', 'Marietta, PA', 'Lebanon, Pa', 'Harrisburg',
#        'Elizabethtown, Pa', 'Elizabethtown, PA', 'PA'], dtype=object)

# %% [markdown]
# Now let's do some grouping and sorting. We are using Pandas to do our analysis, much like last week.

# %%
grouped_tweets = df_tweets.groupby('location')
count_tweets = grouped_tweets['location'].count()
df_count_tweets = count_tweets.to_frame()
df_count_tweets.columns = ['Count']
df_count_tweets.index.names = ['Location']
df_count_tweets.sort_index()
# Out:
#                      Count
# Location
# Bay, Gulf of Mexico      1
# Carlisle, PA             1
# Harrisburg, PA           4
# Hershey, PA              1
# Highspire, PA            1
# Jonestown, PA            1
# Manheim, PA              1
# Mechanicsburg, PA        1
# Mesa, AZ                 1
# Newport Beach, CA        1
# OHIO                     1
# Philadelphia, PA         1

# %% [markdown]
# Let's create a pie chart of these using matplotlib.

# %%
# Create a list of colors (from iWantHue)
colors = ["#697dc6","#5faf4c","#7969de","#b5b246",
          "#cc54bc","#4bad89","#d84577","#4eacd7",
          "#cf4e33","#894ea8","#cf8c42","#d58cc9",
          "#737632","#9f4b75","#c36960"]

# Create a pie chart
plt.pie( df_count_tweets['Count'], labels=df_count_tweets.index.get_values(), shadow=False, colors=colors)

# View the plot drop above
plt.axis('equal')

# View the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# There are quite a few duplicates that we can clearly see, you will likely want to clean this data to rectify this.

# %% [markdown]
# **B** - Next, let's find how many actually have a location and put them on a scatterplot. To do this, we need to find first the rows where lat and long are not None, and then create the plot from just that subset of the data. Let's give it a go.

# %%
# Create a filter from df_tweets filtering only those that have values for lat and lon
df_tweets_with_location = df_tweets[df_tweets.lon.notnull() & df_tweets.lat.notnull()]
df_tweets_with_location
# Out:
#                               tweet_id      lat      lon  \
# 838533954139480064  838533954139480064 -76.8433   40.261
# 838533891992477696  838533891992477696 -76.5624  40.0559
# 838533773448757248  838533773448757248 -76.6512  40.2784
#
#                                                               content  \
# 838533954139480064  Whoa! Glad I'm having smoked steak! This need....
# 838533891992477696  #bigmuddybrewing #galaxy #ipa #nicksbistro #ma...
# 838533773448757248  all smiles when I'm with my bff💗 @ Hershey, Pe...
#
#                            location        user  \
# 838533954139480064  Linglestown, PA  2423758021
# 838533891992477696     Marietta, PA   387974372
# 838533773448757248               PA   615275045
#
#                                                            raw_source  \
# 838533954139480064  {'created_at': 'Sun Mar 05 23:37:28 +0000 2017...
# 838533891992477696  {'created_at': 'Sun Mar 05 23:37:13 +0000 2017...
# 838533773448757248  {'created_at': 'Sun Mar 05 23:36:45 +0000 2017...
#
#                    data_point                            time
# 838533954139480064       none  Sun Mar 05 23:37:28 +0000 2017
# 838533891992477696       none  Sun Mar 05 23:37:13 +0000 2017
# 838533773448757248       none  Sun Mar 05 23:36:45 +0000 2017

# %%
# Use a scatter plot to make a quick visualization of the data points
# NOTE: WHEN I DID THIS, I ONLY HAD SIX OUT OF ABOUT 100 TWEETS!
plt.scatter(df_tweets_with_location['lon'],df_tweets_with_location['lat'], s=25)
plt.show()

# %% [markdown]
# ### 8. Clean the Data
#
# **Clean the Locations** - You saw above that we had a bunch of locations that were very similar. Here, we could use [replace](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.replace.html). For example, we could replace all the variations of **York, PA** with a singular string using something like the following:

# %%
# List of variations of York
variations_of_york = ['York, PA','York PA','York, Pennsylvania','York, Pa','41 W Market Street York, Pa','york P.a. ','York, Pa.']

df_tweets['location'].replace(variations_of_york, 'York, PA')
# Out:
# 836964415278718977      Newport Beach, CA
# 836964383427284994         Harrisburg, PA
# 836964370676596736       Philadelphia, PA
# 836964370508824576      Mechanicsburg, PA
# 836964361717628930                   OHIO
# 836964342289543168           Carlisle, PA
# 836964334005862400         Harrisburg, PA
# 836964333192097792         Harrisburg, PA
# 836964328653778944               Mesa, AZ
# 836964328620322816         Harrisburg, PA
# 836964328360267776          Highspire, PA
# 836964312275116032          Jonestown, PA
# 836964311562088448    Bay, Gulf of Mexico
# 836964303773237248            Manheim, PA
# 836964301709664256           Hershey, PA
# 838533971575246850       Wrightsville, PA
# 838533956991660033          Mount Joy, PA
# 838533954714144768               York, PA
# 838533954139480064        Linglestown, PA
# 838533945801191430          Grantville,PA
# 838533929418248192
# 838533917405761536        Harrisburg , PA
# 838533891992477696           Marietta, PA
# 838533888473509889            Lebanon, Pa
# 838533873097125888               York, PA
# 838533864243007488             Harrisburg
# 838533845075046401
# 838533824724205568      Elizabethtown, Pa
# 838533821863706625      Elizabethtown, PA
# 838533773448757248                     PA
# Name: location, dtype: object

# %% [markdown]
# **Remove Duplicates** - Make sure that we don't get tweets plotted more than once. How would you make sure to only plot unique tweets? We can maybe use [drop_duplicates](http://chrisalbon.com/python/pandas_delete_duplicates.html)

# %% [markdown]
# ### 9. Exporting your Data to CSV
#
# Exporting your dataset is easy, you can use **to_csv()**. This [Stack Exchange](http://stackoverflow.com/questions/16923281/pandas-writing-dataframe-to-csv-file) page will help you.

# %%
df_tweets.to_csv('twitter_data.csv', sep=',', encoding='utf-8')

# %% [markdown]
# ### Problem Set 3 - Extend What You Have Learned
#
# Now that you know how to scrape data from Twitter, let's extend the exercise a little so you can show us what you know. This time you will set up the scraper to get data around MIT and scrape data for 20 minutes. Then you will visualize it with  and visualize. Think about what you would need to change to do that.
#
# Once you have the new JSON file of Boston tweets you should a pie chart and scatterplot of your collected tweets. When you are creating your dataset, you should get at least two different attributes returned by the Twitter API (we got many of them above, so base it off of that example). Atleast one of them should be the tweet id. Make sure you remove and duplicate tweets (if any). Expanding on the above, then save the data to a CSV.
#
# Make sure you get your own Twitter Key.
#
# #### Deliverables
#
# **1** - Using the Twitter REST API, collect Tweets from Boston for 30 min. Note how you set the time in the above example (in the **run_all()** function), it was in seconds. How would you do that here?
#
# **2** - Create a Pie Chart showing a summary of tweets by user location. Please clean up the data so that multiple variations of the same location name are replaced with one variation.
#
# **3** - Create a Scatterplot showing all of the tweets that had a latitude and longitude.
#
# **4** - Pick a search term, such as *Trump* or *#Trump* and collect 15 minutes of tweets on it. Use the same lat/lon for Boston as you used above.
#
# **5** - Export the entirety of your scraped Twitter datasets (one with a search term, one without) to two CSV files. We will be checking this CSV file for duplicates. So clean your file.
#
# ### What to Give Us on Stellar
#
# 1 - Create a new Jupyter notebook that contains your scraper code. You can copy much of this one, but customize it. Submit the new Jupyter notebook, which includes your pie chart and scatterplot.
#
# 2 - Your final CSV files.

# %%
# Import libraries
import json
import time
import threading
from datetime import datetime
from twython import Twython

# Imports the keys from the python file
from twitter_key import api_key, api_secret

# %%
# Assigns the keys to the variables
APP_KEY = api_key
APP_SECRET = api_secret

# Create a Twython object called Twitter
# Set this up using your Twitter Keys
# Say we are going to use OAuth 2
twython_setup = Twython(APP_KEY, APP_SECRET, oauth_version=2)

# Get an OAuth2 access token, save as variable so we can launch our 
OAUTH2_ACCESS_TOKEN = twython_setup.obtain_access_token()

# Create a Twython Object we will use for our access to the API
my_twython = Twython(APP_KEY, access_token=OAUTH2_ACCESS_TOKEN)

# %%
# Input the search term you want to search on
search_term='' # SET A SEARCH TERM LIKE 'TRUMP'
# CAN LEAVE search_term BLANK IF YOU WANT ALL TWEETS NEAR A SPECIFIC LOCATION
# Setup a Lat Lon
latlong=[42.3601,-71.0589] # Boston, MA 42.3601° N, 71.0589° W
# Setup a search distance
distance='30mi'
# Set result type (can be 'recent', 'popular', or 'mixed')
type_of_result='recent'
# Set number of results (up to 100, remember you can only get 450 in 15 minutes)
number_of_tweets=15


# Fetches tweets with a given query at a given lat-long.
def get_tweets_by_location( latlong=None ):
    # Uses the search function to hit the APIs endpoints and look for recent tweets within the area
    results = my_twython.search(q=search_term, geocode=str(latlong[0])+','+str(latlong[1])+','+ distance, result_type=type_of_result, count=number_of_tweets)
    # Returns the only the statuses from the resulting JSON
    return results['statuses']

# test run our function
get_tweets_by_location(latlong)
# Out:
# [{'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Mar 06 00:06:12 +0000 2017',
#   'entities': {'hashtags': [], 'symbols': [], 'urls': [], 'user_mentions': []},
#   'favorite_count': 2,
#   'favorited': False,
#   'geo': None,
#   'id': 838541183550906370,
#   'id_str': '838541183550906370',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'text': 'Terry Rozier making things happen tonight!',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Wed Aug 31 06:23:57 +0000 2016',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'Sports Fan, Gamer, Youtube Entertainer\nBusiness Email:\nShake4ndbake.business@gmail.com',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'youtube.com/Shake4ndBake',
#        'expanded_url': 'https://www.youtube.com/Shake4ndBake',
#        'indices': [0, 23],
#        'url': 'https://t.co/J8y3BIeSJe'}]}},
#    'favourites_count': 11411,
#    'follow_request_sent': None,
#    'followers_count': 23540,
#    'following': None,
#    'friends_count': 1184,
#    'geo_enabled': False,
#    'has_extended_profile': True,
#    'id': 770869718303596544,
#    'id_str': '770869718303596544',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 46,
#    'location': 'Boston, MA',
#    'name': 'Shake4ndbake',
#    'notifications': None,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/820148335684255744/5aVLcGkr_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/820148335684255744/5aVLcGkr_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'ItsShake4ndbake',
#    'statuses_count': 14952,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'none',
#    'url': 'https://t.co/J8y3BIeSJe',
#    'utc_offset': -18000,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Mar 06 00:06:12 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'theatlantic.ga/5zL',
#      'expanded_url': 'http://theatlantic.ga/5zL',
#      'indices': [86, 109],
#      'url': 'https://t.co/g2WENSoOLZ'},
#     {'display_url': 'twitter.com/i/web/status/8…',
#      'expanded_url': 'https://twitter.com/i/web/status/838541183529836546',
#      'indices': [111, 134],
#      'url': 'https://t.co/LnfMUtvRe3'}],
#    'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838541183529836546,
#   'id_str': '838541183529836546',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="https://dlvrit.com/" rel="nofollow">dlvr.it</a>',
#   'text': 'Proof Found Barack Obama is Behind Anti-Trump Movement, Tens of Thousands in Training https://t.co/g2WENSoOLZ… https://t.co/LnfMUtvRe3',
#   'truncated': True,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sun Feb 19 02:49:27 +0000 2017',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'Republican #Conservative #AntiIslam #NotPC #AmericaFirst',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 0,
#    'follow_request_sent': None,
#    'followers_count': 2647,
#    'following': None,
#    'friends_count': 3386,
#    'geo_enabled': False,
#    'has_extended_profile': True,
#    'id': 833146448027979776,
#    'id_str': '833146448027979776',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'es',
#    'listed_count': 2,
#    'location': 'Boston, MA',
#    'name': 'Our President Trump',
#    'notifications': None,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/833146448027979776/1487472961',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/833147836082569216/kYgKhPXT_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/833147836082569216/kYgKhPXT_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'OurMrTrump',
#    'statuses_count': 1889,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Mar 06 00:06:11 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 390254809,
#      'id_str': '390254809',
#      'indices': [3, 14],
#      'name': 'A Money',
#      'screen_name': 'arielsoto5'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838541182380748800,
#   'id_str': '838541182380748800',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 2,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Sun Mar 05 22:57:11 +0000 2017',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': []},
#    'favorite_count': 1,
#    'favorited': False,
#    'geo': None,
#    'id': 838523816196341760,
#    'id_str': '838523816196341760',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 2,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'text': "I'm broke baby",
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Thu Oct 13 18:08:08 +0000 2011',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': "don't need one",
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 727,
#     'follow_request_sent': None,
#     'followers_count': 301,
#     'following': None,
#     'friends_count': 196,
#     'geo_enabled': False,
#     'has_extended_profile': True,
#     'id': 390254809,
#     'id_str': '390254809',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 1,
#     'location': 'boston ma',
#     'name': 'A Money',
#     'notifications': None,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/390254809/1428544751',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/763946954766168065/HkwQu63T_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/763946954766168065/HkwQu63T_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'arielsoto5',
#     'statuses_count': 13428,
#     'time_zone': 'Atlantic Time (Canada)',
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': -14400,
#     'verified': False}},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': "RT @arielsoto5: I'm broke baby",
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Mon Jun 27 03:41:53 +0000 2011',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': "FSU '17",
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 1611,
#    'follow_request_sent': None,
#    'followers_count': 883,
#    'following': None,
#    'friends_count': 584,
#    'geo_enabled': True,
#    'has_extended_profile': True,
#    'id': 324729982,
#    'id_str': '324729982',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 2,
#    'location': 'Boston, MA',
#    'name': 'Don K',
#    'notifications': None,
#    'profile_background_color': '131516',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/556942507/rsx7-1-1.jpg',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/556942507/rsx7-1-1.jpg',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/324729982/1470629569',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/819257066082750465/9hc6zxYg_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/819257066082750465/9hc6zxYg_normal.jpg',
#    'profile_link_color': '009999',
#    'profile_sidebar_border_color': 'EEEEEE',
#    'profile_sidebar_fill_color': 'EFEFEF',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'BummieKerls',
#    'statuses_count': 89120,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': -18000,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Mar 06 00:06:11 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'savingzev.1articleslist.us/client/eVVWe/d…',
#      'expanded_url': 'http://savingzev.1articleslist.us/client/eVVWe/dN9oK/dBBpW/ymrj7',
#      'indices': [62, 85],
#      'url': 'https://t.co/EKwTIuiUzM'}],
#    'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838541181973901312,
#   'id_str': '838541181973901312',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'text': 'Woman Accidentally Drops Engagement Ring In Homeless Man’s -- https://t.co/EKwTIuiUzM',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Wed Jan 25 04:12:49 +0000 2017',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': '',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 0,
#    'follow_request_sent': None,
#    'followers_count': 868,
#    'following': None,
#    'friends_count': 4441,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 824107731346800640,
#    'id_str': '824107731346800640',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 3,
#    'location': 'Lowell',
#    'name': 'Soledad Carmella',
#    'notifications': None,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/824107731346800640/1485317740',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/824108355887042561/udi2EP20_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/824108355887042561/udi2EP20_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'LokshinVadimka',
#    'statuses_count': 17609,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Mar 06 00:06:11 +0000 2017',
#   'entities': {'hashtags': [{'indices': [98, 111], 'text': 'RaiseTheRoof'}],
#    'media': [{'display_url': 'pic.twitter.com/Xuu020vsjj',
#      'expanded_url': 'https://twitter.com/LaxSportsNet/status/837722337701146628/video/1',
#      'id': 837722260530163712,
#      'id_str': '837722260530163712',
#      'indices': [112, 135],
#      'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/837722260530163712/pu/img/McpbEAccpsBAW_em.jpg',
#      'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/837722260530163712/pu/img/McpbEAccpsBAW_em.jpg',
#      'sizes': {'large': {'h': 576, 'resize': 'fit', 'w': 1024},
#       'medium': {'h': 338, 'resize': 'fit', 'w': 600},
#       'small': {'h': 191, 'resize': 'fit', 'w': 340},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'source_status_id': 837722337701146628,
#      'source_status_id_str': '837722337701146628',
#      'source_user_id': 3111512109,
#      'source_user_id_str': '3111512109',
#      'type': 'photo',
#      'url': 'https://t.co/Xuu020vsjj'}],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 3111512109,
#      'id_str': '3111512109',
#      'indices': [3, 16],
#      'name': 'Lax Sports Network',
#      'screen_name': 'LaxSportsNet'},
#     {'id': 143495746,
#      'id_str': '143495746',
#      'indices': [22, 36],
#      'name': 'Myles Jones',
#      'screen_name': 'MylesJones_15'},
#     {'id': 1643988212,
#      'id_str': '1643988212',
#      'indices': [59, 73],
#      'name': 'lyle thompson',
#      'screen_name': 'lyle4thompson'},
#     {'id': 46705208,
#      'id_str': '46705208',
#      'indices': [84, 96],
#      'name': 'Chesapeake Bayhawks',
#      'screen_name': 'TheBayhawks'}]},
#   'extended_entities': {'media': [{'additional_media_info': {'monetizable': False,
#       'source_user': {'contributors_enabled': False,
#        'created_at': 'Tue Mar 24 20:43:10 +0000 2015',
#        'default_profile': False,
#        'default_profile_image': False,
#        'description': '24/7 all-laxess digital network dedicated to lacrosse. Streaming live and on-demand games with news & analysis. Download app: https://t.co/fcKmsps231',
#        'entities': {'description': {'urls': [{'display_url': 'appsto.re/us/Y_TV-.i',
#            'expanded_url': 'http://appsto.re/us/Y_TV-.i',
#            'indices': [126, 149],
#            'url': 'https://t.co/fcKmsps231'}]},
#         'url': {'urls': [{'display_url': 'bit.ly/LSNLive1',
#            'expanded_url': 'http://bit.ly/LSNLive1',
#            'indices': [0, 23],
#            'url': 'https://t.co/qYo37lLVuD'}]}},
#        'favourites_count': 6230,
#        'follow_request_sent': None,
#        'followers_count': 11082,
#        'following': None,
#        'friends_count': 2608,
#        'geo_enabled': False,
#        'has_extended_profile': True,
#        'id': 3111512109,
#        'id_str': '3111512109',
#        'is_translation_enabled': False,
#        'is_translator': False,
#        'lang': 'en',
#        'listed_count': 73,
#        'location': 'Boston, MA',
#        'name': 'Lax Sports Network',
#        'notifications': None,
#        'profile_background_color': 'C0DEED',
#        'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/595620867893108736/NSMDwB-O.jpg',
#        'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/595620867893108736/NSMDwB-O.jpg',
#        'profile_background_tile': False,
#        'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3111512109/1470233121',
#        'profile_image_url': 'http://pbs.twimg.com/profile_images/680147009098104832/ErxGRvgr_normal.jpg',
#        'profile_image_url_https': 'https://pbs.twimg.com/profile_images/680147009098104832/ErxGRvgr_normal.jpg',
#        'profile_link_color': 'DD2E44',
#        'profile_sidebar_border_color': 'C0DEED',
#        'profile_sidebar_fill_color': 'DDEEF6',
#        'profile_text_color': '333333',
#        'profile_use_background_image': False,
#        'protected': False,
#        'screen_name': 'LaxSportsNet',
#        'statuses_count': 8498,
#        'time_zone': 'Eastern Time (US & Canada)',
#        'translator_type': 'none',
#        'url': 'https://t.co/qYo37lLVuD',
#        'utc_offset': -18000,
#        'verified': False}},
#      'display_url': 'pic.twitter.com/Xuu020vsjj',
#      'expanded_url': 'https://twitter.com/LaxSportsNet/status/837722337701146628/video/1',
#      'id': 837722260530163712,
#      'id_str': '837722260530163712',
#      'indices': [112, 135],
#      'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/837722260530163712/pu/img/McpbEAccpsBAW_em.jpg',
#      'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/837722260530163712/pu/img/McpbEAccpsBAW_em.jpg',
#      'sizes': {'large': {'h': 576, 'resize': 'fit', 'w': 1024},
#       'medium': {'h': 338, 'resize': 'fit', 'w': 600},
#       'small': {'h': 191, 'resize': 'fit', 'w': 340},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'source_status_id': 837722337701146628,
#      'source_status_id_str': '837722337701146628',
#      'source_user_id': 3111512109,
#      'source_user_id_str': '3111512109',
#      'type': 'video',
#      'url': 'https://t.co/Xuu020vsjj',
#      'video_info': {'aspect_ratio': [16, 9],
#       'duration_millis': 5639,
#       'variants': [{'content_type': 'application/x-mpegURL',
#         'url': 'https://video.twimg.com/ext_tw_video/837722260530163712/pu/pl/vxBnKYH-mCD8bSx3.m3u8'},
#        {'bitrate': 2176000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/ext_tw_video/837722260530163712/pu/vid/1280x720/rLcS5hLob6yfbQtj.mp4'},
#        {'bitrate': 320000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/ext_tw_video/837722260530163712/pu/vid/320x180/zT4VjVtsHvXtW5A3.mp4'},
#        {'content_type': 'application/dash+xml',
#         'url': 'https://video.twimg.com/ext_tw_video/837722260530163712/pu/pl/vxBnKYH-mCD8bSx3.mpd'},
#        {'bitrate': 832000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/ext_tw_video/837722260530163712/pu/vid/640x360/KvMF00OYsTvMW5OJ.mp4'}]}}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838541181718003712,
#   'id_str': '838541181718003712',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 11,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Fri Mar 03 17:52:24 +0000 2017',
#    'entities': {'hashtags': [{'indices': [80, 93], 'text': 'RaiseTheRoof'}],
#     'media': [{'display_url': 'pic.twitter.com/Xuu020vsjj',
#       'expanded_url': 'https://twitter.com/LaxSportsNet/status/837722337701146628/video/1',
#       'id': 837722260530163712,
#       'id_str': '837722260530163712',
#       'indices': [94, 117],
#       'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/837722260530163712/pu/img/McpbEAccpsBAW_em.jpg',
#       'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/837722260530163712/pu/img/McpbEAccpsBAW_em.jpg',
#       'sizes': {'large': {'h': 576, 'resize': 'fit', 'w': 1024},
#        'medium': {'h': 338, 'resize': 'fit', 'w': 600},
#        'small': {'h': 191, 'resize': 'fit', 'w': 340},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/Xuu020vsjj'}],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 143495746,
#       'id_str': '143495746',
#       'indices': [4, 18],
#       'name': 'Myles Jones',
#       'screen_name': 'MylesJones_15'},
#      {'id': 1643988212,
#       'id_str': '1643988212',
#       'indices': [41, 55],
#       'name': 'lyle thompson',
#       'screen_name': 'lyle4thompson'},
#      {'id': 46705208,
#       'id_str': '46705208',
#       'indices': [66, 78],
#       'name': 'Chesapeake Bayhawks',
#       'screen_name': 'TheBayhawks'}]},
#    'extended_entities': {'media': [{'additional_media_info': {'monetizable': False},
#       'display_url': 'pic.twitter.com/Xuu020vsjj',
#       'expanded_url': 'https://twitter.com/LaxSportsNet/status/837722337701146628/video/1',
#       'id': 837722260530163712,
#       'id_str': '837722260530163712',
#       'indices': [94, 117],
#       'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/837722260530163712/pu/img/McpbEAccpsBAW_em.jpg',
#       'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/837722260530163712/pu/img/McpbEAccpsBAW_em.jpg',
#       'sizes': {'large': {'h': 576, 'resize': 'fit', 'w': 1024},
#        'medium': {'h': 338, 'resize': 'fit', 'w': 600},
#        'small': {'h': 191, 'resize': 'fit', 'w': 340},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'video',
#       'url': 'https://t.co/Xuu020vsjj',
#       'video_info': {'aspect_ratio': [16, 9],
#        'duration_millis': 5639,
#        'variants': [{'content_type': 'application/x-mpegURL',
#          'url': 'https://video.twimg.com/ext_tw_video/837722260530163712/pu/pl/vxBnKYH-mCD8bSx3.m3u8'},
#         {'bitrate': 2176000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/ext_tw_video/837722260530163712/pu/vid/1280x720/rLcS5hLob6yfbQtj.mp4'},
#         {'bitrate': 320000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/ext_tw_video/837722260530163712/pu/vid/320x180/zT4VjVtsHvXtW5A3.mp4'},
#         {'content_type': 'application/dash+xml',
#          'url': 'https://video.twimg.com/ext_tw_video/837722260530163712/pu/pl/vxBnKYH-mCD8bSx3.mpd'},
#         {'bitrate': 832000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/ext_tw_video/837722260530163712/pu/vid/640x360/KvMF00OYsTvMW5OJ.mp4'}]}}]},
#    'favorite_count': 47,
#    'favorited': False,
#    'geo': None,
#    'id': 837722337701146628,
#    'id_str': '837722337701146628',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 11,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'text': 'So, @MylesJones_15 how do you feel about @lyle4thompson coming to @TheBayhawks? #RaiseTheRoof https://t.co/Xuu020vsjj',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Tue Mar 24 20:43:10 +0000 2015',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': '24/7 all-laxess digital network dedicated to lacrosse. Streaming live and on-demand games with news & analysis. Download app: https://t.co/fcKmsps231',
#     'entities': {'description': {'urls': [{'display_url': 'appsto.re/us/Y_TV-.i',
#         'expanded_url': 'http://appsto.re/us/Y_TV-.i',
#         'indices': [126, 149],
#         'url': 'https://t.co/fcKmsps231'}]},
#      'url': {'urls': [{'display_url': 'bit.ly/LSNLive1',
#         'expanded_url': 'http://bit.ly/LSNLive1',
#         'indices': [0, 23],
#         'url': 'https://t.co/qYo37lLVuD'}]}},
#     'favourites_count': 6230,
#     'follow_request_sent': None,
#     'followers_count': 11082,
#     'following': None,
#     'friends_count': 2608,
#     'geo_enabled': False,
#     'has_extended_profile': True,
#     'id': 3111512109,
#     'id_str': '3111512109',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 73,
#     'location': 'Boston, MA',
#     'name': 'Lax Sports Network',
#     'notifications': None,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/595620867893108736/NSMDwB-O.jpg',
#     'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/595620867893108736/NSMDwB-O.jpg',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3111512109/1470233121',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/680147009098104832/ErxGRvgr_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/680147009098104832/ErxGRvgr_normal.jpg',
#     'profile_link_color': 'DD2E44',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': False,
#     'protected': False,
#     'screen_name': 'LaxSportsNet',
#     'statuses_count': 8498,
#     'time_zone': 'Eastern Time (US & Canada)',
#     'translator_type': 'none',
#     'url': 'https://t.co/qYo37lLVuD',
#     'utc_offset': -18000,
#     'verified': False}},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': 'RT @LaxSportsNet: So, @MylesJones_15 how do you feel about @lyle4thompson coming to @TheBayhawks? #RaiseTheRoof https://t.co/Xuu020vsjj',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Tue Mar 24 20:43:10 +0000 2015',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': '24/7 all-laxess digital network dedicated to lacrosse. Streaming live and on-demand games with news & analysis. Download app: https://t.co/fcKmsps231',
#    'entities': {'description': {'urls': [{'display_url': 'appsto.re/us/Y_TV-.i',
#        'expanded_url': 'http://appsto.re/us/Y_TV-.i',
#        'indices': [126, 149],
#        'url': 'https://t.co/fcKmsps231'}]},
#     'url': {'urls': [{'display_url': 'bit.ly/LSNLive1',
#        'expanded_url': 'http://bit.ly/LSNLive1',
#        'indices': [0, 23],
#        'url': 'https://t.co/qYo37lLVuD'}]}},
#    'favourites_count': 6230,
#    'follow_request_sent': None,
#    'followers_count': 11082,
#    'following': None,
#    'friends_count': 2608,
#    'geo_enabled': False,
#    'has_extended_profile': True,
#    'id': 3111512109,
#    'id_str': '3111512109',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 73,
#    'location': 'Boston, MA',
#    'name': 'Lax Sports Network',
#    'notifications': None,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/595620867893108736/NSMDwB-O.jpg',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/595620867893108736/NSMDwB-O.jpg',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3111512109/1470233121',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/680147009098104832/ErxGRvgr_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/680147009098104832/ErxGRvgr_normal.jpg',
#    'profile_link_color': 'DD2E44',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': False,
#    'protected': False,
#    'screen_name': 'LaxSportsNet',
#    'statuses_count': 8498,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'none',
#    'url': 'https://t.co/qYo37lLVuD',
#    'utc_offset': -18000,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Mar 06 00:06:11 +0000 2017',
#   'entities': {'hashtags': [{'indices': [0, 4], 'text': 'MLB'}],
#    'symbols': [],
#    'urls': [{'display_url': 'mlb.mlb.com/news/article/m…',
#      'expanded_url': 'http://mlb.mlb.com/news/article/mlb/brewers-pleased-with-eric-thames-this-spring?ymd=20170305&content_id=218061464&vkey=news_mlb&utm_source=dlvr.it&utm_medium=twitter',
#      'indices': [60, 83],
#      'url': 'https://t.co/tT1oSQpOCY'},
#     {'display_url': 'playerpress.com',
#      'expanded_url': 'http://playerpress.com',
#      'indices': [84, 107],
#      'url': 'https://t.co/fguDlCphyy'}],
#    'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838541181151670272,
#   'id_str': '838541181151670272',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="https://dlvrit.com/" rel="nofollow">dlvr.it</a>',
#   'text': "#MLB Wire: Counsell pleased with Thames' first week in camp https://t.co/tT1oSQpOCY https://t.co/fguDlCphyy",
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Thu Mar 11 05:59:50 +0000 2010',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'We cover the Boston Red Sox and the MLB 24/7. Player Press is a curator of interesting sports content across the web. Sports news, sports gossip... @playerpress',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'playerpress.com',
#        'expanded_url': 'http://playerpress.com',
#        'indices': [0, 22],
#        'url': 'http://t.co/SW2sBBsihI'}]}},
#    'favourites_count': 0,
#    'follow_request_sent': None,
#    'followers_count': 408,
#    'following': None,
#    'friends_count': 458,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 121977418,
#    'id_str': '121977418',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 59,
#    'location': 'Boston , MA',
#    'name': 'Boston Red Sox Wire',
#    'notifications': None,
#    'profile_background_color': '1A1B1F',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1027293467/wickedsoxlogo_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1027293467/wickedsoxlogo_normal.jpg',
#    'profile_link_color': '2FC2EF',
#    'profile_sidebar_border_color': '181A1E',
#    'profile_sidebar_fill_color': '252429',
#    'profile_text_color': '666666',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'redsoxpress',
#    'statuses_count': 108209,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'none',
#    'url': 'http://t.co/SW2sBBsihI',
#    'utc_offset': -18000,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Mar 06 00:06:11 +0000 2017',
#   'entities': {'hashtags': [],
#    'media': [{'display_url': 'pic.twitter.com/aQEU6yKYRE',
#      'expanded_url': 'https://twitter.com/thirtyARTsix/status/838541178744242180/photo/1',
#      'id': 838541166446538752,
#      'id_str': '838541166446538752',
#      'indices': [43, 66],
#      'media_url': 'http://pbs.twimg.com/media/C6MYv4OWcAA3OWq.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/C6MYv4OWcAA3OWq.jpg',
#      'sizes': {'large': {'h': 1940, 'resize': 'fit', 'w': 2048},
#       'medium': {'h': 1137, 'resize': 'fit', 'w': 1200},
#       'small': {'h': 644, 'resize': 'fit', 'w': 680},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'type': 'photo',
#      'url': 'https://t.co/aQEU6yKYRE'}],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': []},
#   'extended_entities': {'media': [{'display_url': 'pic.twitter.com/aQEU6yKYRE',
#      'expanded_url': 'https://twitter.com/thirtyARTsix/status/838541178744242180/photo/1',
#      'id': 838541166446538752,
#      'id_str': '838541166446538752',
#      'indices': [43, 66],
#      'media_url': 'http://pbs.twimg.com/media/C6MYv4OWcAA3OWq.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/C6MYv4OWcAA3OWq.jpg',
#      'sizes': {'large': {'h': 1940, 'resize': 'fit', 'w': 2048},
#       'medium': {'h': 1137, 'resize': 'fit', 'w': 1200},
#       'small': {'h': 644, 'resize': 'fit', 'w': 680},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'type': 'photo',
#      'url': 'https://t.co/aQEU6yKYRE'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838541178744242180,
#   'id_str': '838541178744242180',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': 'Getting more scribbling done this weekend. https://t.co/aQEU6yKYRE',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Wed Feb 29 17:50:00 +0000 2012',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Pop culture portrait artist. Assistant charge scenic artist at the American Repertory Theater. Surly art fart. Anxiety, ahoy!',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'thirtyartsix.com',
#        'expanded_url': 'http://www.thirtyartsix.com',
#        'indices': [0, 23],
#        'url': 'https://t.co/T2ZcoxRrKc'}]}},
#    'favourites_count': 1384,
#    'follow_request_sent': None,
#    'followers_count': 484,
#    'following': None,
#    'friends_count': 334,
#    'geo_enabled': False,
#    'has_extended_profile': True,
#    'id': 509064493,
#    'id_str': '509064493',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 33,
#    'location': 'Boston, MA',
#    'name': 'Heather Morris',
#    'notifications': None,
#    'profile_background_color': '464F51',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/448034649/birdbackground.jpg',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/448034649/birdbackground.jpg',
#    'profile_background_tile': True,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/509064493/1488728598',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/792046349869015040/yrvQ43FN_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/792046349869015040/yrvQ43FN_normal.jpg',
#    'profile_link_color': '9A954D',
#    'profile_sidebar_border_color': 'D9B17E',
#    'profile_sidebar_fill_color': 'EADEAA',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'thirtyARTsix',
#    'statuses_count': 10926,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'none',
#    'url': 'https://t.co/T2ZcoxRrKc',
#    'utc_offset': -18000,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Mar 06 00:06:10 +0000 2017',
#   'entities': {'hashtags': [], 'symbols': [], 'urls': [], 'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838541177196425216,
#   'id_str': '838541177196425216',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'text': 'What a hustle play from Terry Rozier! Misses jumper, flies in to break up PHX pass, saves ball from going out of bounds, IT cans 3.',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Thu Jun 18 17:28:05 +0000 2009',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Celtics Reporter/Analyst. Manage @celtics official team content. IC Bomber. These opinions are mine, not those of the Celtics. Reel: https://t.co/T83sj0sO0s',
#    'entities': {'description': {'urls': [{'display_url': 'bit.ly/2mLQd0Y',
#        'expanded_url': 'http://bit.ly/2mLQd0Y',
#        'indices': [133, 156],
#        'url': 'https://t.co/T83sj0sO0s'}]},
#     'url': {'urls': [{'display_url': 'MarcDAmico.net',
#        'expanded_url': 'http://MarcDAmico.net',
#        'indices': [0, 22],
#        'url': 'http://t.co/DdnizXv6JE'}]}},
#    'favourites_count': 1614,
#    'follow_request_sent': None,
#    'followers_count': 14431,
#    'following': None,
#    'friends_count': 623,
#    'geo_enabled': True,
#    'has_extended_profile': True,
#    'id': 48421907,
#    'id_str': '48421907',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 495,
#    'location': 'Boston, MA',
#    'name': "Marc D'Amico",
#    'notifications': None,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/716705970/b090c6973f74dcead3469e0a97b11fb2.jpeg',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/716705970/b090c6973f74dcead3469e0a97b11fb2.jpeg',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/48421907/1398777879',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/817592124057198593/tBwSvsif_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/817592124057198593/tBwSvsif_normal.jpg',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'Marc_DAmico',
#    'statuses_count': 17647,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'none',
#    'url': 'http://t.co/DdnizXv6JE',
#    'utc_offset': -18000,
#    'verified': True}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Mar 06 00:06:10 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 24761167,
#      'id_str': '24761167',
#      'indices': [3, 18],
#      'name': 'Eve Bridburg',
#      'screen_name': 'eve_grubstreet'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838541176579973120,
#   'id_str': '838541176579973120',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 2,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Sun Mar 05 23:39:52 +0000 2017',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [{'display_url': 'nyti.ms/2mBTNuM',
#       'expanded_url': 'https://nyti.ms/2mBTNuM',
#       'indices': [114, 137],
#       'url': 'https://t.co/NG1uOTZc1p'}],
#     'user_mentions': []},
#    'favorite_count': 4,
#    'favorited': False,
#    'geo': None,
#    'id': 838534557561405440,
#    'id_str': '838534557561405440',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 2,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'text': 'NEA funding is essential for access to arts education.  How to Block Trump Arts Cuts? Groups Look for G.O.P. Help https://t.co/NG1uOTZc1p',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Mon Mar 16 20:20:35 +0000 2009',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': "Founder & Executive Director GrubStreet where we've been turning humans into better writers and writers into better humans since 1997.",
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'grubstreet.org',
#         'expanded_url': 'http://www.grubstreet.org',
#         'indices': [0, 22],
#         'url': 'http://t.co/NL2NL30rXm'}]}},
#     'favourites_count': 146,
#     'follow_request_sent': None,
#     'followers_count': 2001,
#     'following': None,
#     'friends_count': 1225,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 24761167,
#     'id_str': '24761167',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 141,
#     'location': 'Boston, MA',
#     'name': 'Eve Bridburg',
#     'notifications': None,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/24761167/1403896824',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/2182204880/Photo_on_2012-05-01_at_13.42__4_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/2182204880/Photo_on_2012-05-01_at_13.42__4_normal.jpg',
#     'profile_link_color': '91D2FA',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'eve_grubstreet',
#     'statuses_count': 1555,
#     'time_zone': 'Quito',
#     'translator_type': 'none',
#     'url': 'http://t.co/NL2NL30rXm',
#     'utc_offset': -18000,
#     'verified': False}},
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'text': 'RT @eve_grubstreet: NEA funding is essential for access to arts education.  How to Block Trump Arts Cuts? Groups Look for G.O.P. Help https…',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Mon Nov 05 00:53:36 +0000 2007',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Teaching for Artistic Behavior (TAB)\r\nEngaging Learners Through Artmaking (Teachers College Press 2009)',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'teachingforartisticbehavior.org',
#        'expanded_url': 'http://teachingforartisticbehavior.org',
#        'indices': [0, 22],
#        'url': 'http://t.co/JomVpN4Akg'}]}},
#    'favourites_count': 4584,
#    'follow_request_sent': None,
#    'followers_count': 1176,
#    'following': None,
#    'friends_count': 495,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 9951902,
#    'id_str': '9951902',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 80,
#    'location': 'US',
#    'name': 'katherine douglas',
#    'notifications': None,
#    'profile_background_color': '0E0D02',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/154509652/xa73abba2758cefcb16e9c23cde21ab8.jpg',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/154509652/xa73abba2758cefcb16e9c23cde21ab8.jpg',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/9951902/1353189527',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1591145008/k._nj_2_2_normal.jpeg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1591145008/k._nj_2_2_normal.jpeg',
#    'profile_link_color': '39BD91',
#    'profile_sidebar_border_color': 'BEDFB6',
#    'profile_sidebar_fill_color': '0E0D02',
#    'profile_text_color': '895429',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'twoducks',
#    'statuses_count': 7619,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'none',
#    'url': 'http://t.co/JomVpN4Akg',
#    'utc_offset': -18000,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Mar 06 00:06:10 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 14345566,
#      'id_str': '14345566',
#      'indices': [0, 12],
#      'name': 'TheBloggess',
#      'screen_name': 'TheBloggess'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838541175585968129,
#   'id_str': '838541175585968129',
#   'in_reply_to_screen_name': 'TheBloggess',
#   'in_reply_to_status_id': 838479102856286208,
#   'in_reply_to_status_id_str': '838479102856286208',
#   'in_reply_to_user_id': 14345566,
#   'in_reply_to_user_id_str': '14345566',
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': '@TheBloggess apparently something called "criminal" is quite good.',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sat May 02 00:54:05 +0000 2009',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'A Canadian girl on an American adventure',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 221,
#    'follow_request_sent': None,
#    'followers_count': 84,
#    'following': None,
#    'friends_count': 265,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 37095045,
#    'id_str': '37095045',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 0,
#    'location': 'Boston, MA',
#    'name': 'Erin Galloway',
#    'notifications': None,
#    'profile_background_color': '8B542B',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme8/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme8/bg.gif',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/720000006812540928/4PR2QmTE_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/720000006812540928/4PR2QmTE_normal.jpg',
#    'profile_link_color': '9D582E',
#    'profile_sidebar_border_color': 'D9B17E',
#    'profile_sidebar_fill_color': 'DD8A5A',
#    'profile_text_color': '603B2F',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'eringalloway',
#    'statuses_count': 890,
#    'time_zone': 'Quito',
#    'translator_type': 'none',
# ...
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'RedSoxJunkies',
#     'statuses_count': 742,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': None,
#     'verified': False}},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': 'RT @RedSoxJunkies: Benintendi has already learned how to use left field at fenway.  Dudes gonna hit 1000 doubles off the wall.',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Fri Jan 20 23:00:00 +0000 2012',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': '"Bum"  ✝#32 – Instagram: e_b_u_m_1_0 –Snapchat: bum_32 – #WinDanceRepeat',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 7446,
#    'follow_request_sent': None,
#    'followers_count': 482,
#    'following': None,
#    'friends_count': 901,
#    'geo_enabled': True,
#    'has_extended_profile': True,
#    'id': 469741323,
#    'id_str': '469741323',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 5,
#    'location': '',
#    'name': 'Ethan Bumgarner',
#    'notifications': None,
#    'profile_background_color': '022330',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/590041105/x9d38a530080d57b56b85d983d2e38b5.jpg',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/590041105/x9d38a530080d57b56b85d983d2e38b5.jpg',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/469741323/1476234001',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/834402064457412608/TNRaRlDU_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/834402064457412608/TNRaRlDU_normal.jpg',
#    'profile_link_color': '981CEB',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': '3B3B3B',
#    'profile_text_color': '989898',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'E_Bum10',
#    'statuses_count': 5630,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Mar 06 00:06:09 +0000 2017',
#   'entities': {'hashtags': [],
#    'media': [{'display_url': 'pic.twitter.com/kH1m512AVl',
#      'expanded_url': 'https://twitter.com/celtics/status/838540966201966592/video/1',
#      'id': 838540946081882112,
#      'id_str': '838540946081882112',
#      'indices': [87, 110],
#      'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/838540946081882112/pu/img/71YSggs7gSv5YENp.jpg',
#      'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/838540946081882112/pu/img/71YSggs7gSv5YENp.jpg',
#      'sizes': {'large': {'h': 576, 'resize': 'fit', 'w': 1024},
#       'medium': {'h': 338, 'resize': 'fit', 'w': 600},
#       'small': {'h': 191, 'resize': 'fit', 'w': 340},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'source_status_id': 838540966201966592,
#      'source_status_id_str': '838540966201966592',
#      'source_user_id': 18139461,
#      'source_user_id_str': '18139461',
#      'type': 'photo',
#      'url': 'https://t.co/kH1m512AVl'}],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 18139461,
#      'id_str': '18139461',
#      'indices': [3, 11],
#      'name': 'Boston Celtics',
#      'screen_name': 'celtics'}]},
#   'extended_entities': {'media': [{'additional_media_info': {'monetizable': False,
#       'source_user': {'contributors_enabled': False,
#        'created_at': 'Mon Dec 15 16:19:50 +0000 2008',
#        'default_profile': False,
#        'default_profile_image': False,
#        'description': 'The Official Feed of the 17-Time World Champions.',
#        'entities': {'description': {'urls': []},
#         'url': {'urls': [{'display_url': 'nba.com/celtics/ticket…',
#            'expanded_url': 'http://www.nba.com/celtics/tickets/',
#            'indices': [0, 22],
#            'url': 'http://t.co/fs0Hxtjf2C'}]}},
#        'favourites_count': 438,
#        'follow_request_sent': None,
#        'followers_count': 2241891,
#        'following': None,
#        'friends_count': 153,
#        'geo_enabled': False,
#        'has_extended_profile': False,
#        'id': 18139461,
#        'id_str': '18139461',
#        'is_translation_enabled': False,
#        'is_translator': False,
#        'lang': 'en',
#        'listed_count': 10406,
#        'location': 'Boston, MA',
#        'name': 'Boston Celtics',
#        'notifications': None,
#        'profile_background_color': '000000',
#        'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/378800000008579791/9daed4ae0181bf61d75928b4f59ee60c.jpeg',
#        'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/378800000008579791/9daed4ae0181bf61d75928b4f59ee60c.jpeg',
#        'profile_background_tile': False,
#        'profile_banner_url': 'https://pbs.twimg.com/profile_banners/18139461/1461955832',
#        'profile_image_url': 'http://pbs.twimg.com/profile_images/2815110476/033393c13e6dec0fd6cc5006453fbeb5_normal.png',
#        'profile_image_url_https': 'https://pbs.twimg.com/profile_images/2815110476/033393c13e6dec0fd6cc5006453fbeb5_normal.png',
#        'profile_link_color': '00611B',
#        'profile_sidebar_border_color': '000000',
#        'profile_sidebar_fill_color': 'FFFFFF',
#        'profile_text_color': '333333',
#        'profile_use_background_image': True,
#        'protected': False,
#        'screen_name': 'celtics',
#        'statuses_count': 21999,
#        'time_zone': 'Eastern Time (US & Canada)',
#        'translator_type': 'none',
#        'url': 'http://t.co/fs0Hxtjf2C',
#        'utc_offset': -18000,
#        'verified': True}},
#      'display_url': 'pic.twitter.com/kH1m512AVl',
#      'expanded_url': 'https://twitter.com/celtics/status/838540966201966592/video/1',
#      'id': 838540946081882112,
#      'id_str': '838540946081882112',
#      'indices': [87, 110],
#      'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/838540946081882112/pu/img/71YSggs7gSv5YENp.jpg',
#      'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/838540946081882112/pu/img/71YSggs7gSv5YENp.jpg',
#      'sizes': {'large': {'h': 576, 'resize': 'fit', 'w': 1024},
#       'medium': {'h': 338, 'resize': 'fit', 'w': 600},
#       'small': {'h': 191, 'resize': 'fit', 'w': 340},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'source_status_id': 838540966201966592,
#      'source_status_id_str': '838540966201966592',
#      'source_user_id': 18139461,
#      'source_user_id_str': '18139461',
#      'type': 'video',
#      'url': 'https://t.co/kH1m512AVl',
#      'video_info': {'aspect_ratio': [16, 9],
#       'duration_millis': 9241,
#       'variants': [{'bitrate': 2176000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/ext_tw_video/838540946081882112/pu/vid/1280x720/djXSoWTd7O_YYzXC.mp4'},
#        {'content_type': 'application/x-mpegURL',
#         'url': 'https://video.twimg.com/ext_tw_video/838540946081882112/pu/pl/vSdGc3SVECzfcnfF.m3u8'},
#        {'bitrate': 320000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/ext_tw_video/838540946081882112/pu/vid/320x180/2PVbedbgnQY7imPB.mp4'},
#        {'bitrate': 832000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/ext_tw_video/838540946081882112/pu/vid/640x360/H7vedxWfpzY1KOLy.mp4'},
#        {'content_type': 'application/dash+xml',
#         'url': 'https://video.twimg.com/ext_tw_video/838540946081882112/pu/pl/vSdGc3SVECzfcnfF.mpd'}]}}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838541171848794112,
#   'id_str': '838541171848794112',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 11,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Mon Mar 06 00:05:20 +0000 2017',
#    'entities': {'hashtags': [],
#     'media': [{'display_url': 'pic.twitter.com/kH1m512AVl',
#       'expanded_url': 'https://twitter.com/celtics/status/838540966201966592/video/1',
#       'id': 838540946081882112,
#       'id_str': '838540946081882112',
#       'indices': [74, 97],
#       'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/838540946081882112/pu/img/71YSggs7gSv5YENp.jpg',
#       'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/838540946081882112/pu/img/71YSggs7gSv5YENp.jpg',
#       'sizes': {'large': {'h': 576, 'resize': 'fit', 'w': 1024},
#        'medium': {'h': 338, 'resize': 'fit', 'w': 600},
#        'small': {'h': 191, 'resize': 'fit', 'w': 340},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/kH1m512AVl'}],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': []},
#    'extended_entities': {'media': [{'additional_media_info': {'monetizable': False},
#       'display_url': 'pic.twitter.com/kH1m512AVl',
#       'expanded_url': 'https://twitter.com/celtics/status/838540966201966592/video/1',
#       'id': 838540946081882112,
#       'id_str': '838540946081882112',
#       'indices': [74, 97],
#       'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/838540946081882112/pu/img/71YSggs7gSv5YENp.jpg',
#       'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/838540946081882112/pu/img/71YSggs7gSv5YENp.jpg',
#       'sizes': {'large': {'h': 576, 'resize': 'fit', 'w': 1024},
#        'medium': {'h': 338, 'resize': 'fit', 'w': 600},
#        'small': {'h': 191, 'resize': 'fit', 'w': 340},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'video',
#       'url': 'https://t.co/kH1m512AVl',
#       'video_info': {'aspect_ratio': [16, 9],
#        'duration_millis': 9241,
#        'variants': [{'bitrate': 2176000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/ext_tw_video/838540946081882112/pu/vid/1280x720/djXSoWTd7O_YYzXC.mp4'},
#         {'content_type': 'application/x-mpegURL',
#          'url': 'https://video.twimg.com/ext_tw_video/838540946081882112/pu/pl/vSdGc3SVECzfcnfF.m3u8'},
#         {'bitrate': 320000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/ext_tw_video/838540946081882112/pu/vid/320x180/2PVbedbgnQY7imPB.mp4'},
#         {'bitrate': 832000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/ext_tw_video/838540946081882112/pu/vid/640x360/H7vedxWfpzY1KOLy.mp4'},
#         {'content_type': 'application/dash+xml',
#          'url': 'https://video.twimg.com/ext_tw_video/838540946081882112/pu/pl/vSdGc3SVECzfcnfF.mpd'}]}}]},
#    'favorite_count': 34,
#    'favorited': False,
#    'geo': None,
#    'id': 838540966201966592,
#    'id_str': '838540966201966592',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 11,
#    'retweeted': False,
#    'source': '<a href="http://www.wscouting.com" rel="nofollow">WSC CLIPRO</a>',
#    'text': "Rozier's second straight 3-ball made it a 4-point game late in the third. https://t.co/kH1m512AVl",
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Mon Dec 15 16:19:50 +0000 2008',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'The Official Feed of the 17-Time World Champions.',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'nba.com/celtics/ticket…',
#         'expanded_url': 'http://www.nba.com/celtics/tickets/',
#         'indices': [0, 22],
#         'url': 'http://t.co/fs0Hxtjf2C'}]}},
#     'favourites_count': 438,
#     'follow_request_sent': None,
#     'followers_count': 2241891,
#     'following': None,
#     'friends_count': 153,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 18139461,
#     'id_str': '18139461',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 10406,
#     'location': 'Boston, MA',
#     'name': 'Boston Celtics',
#     'notifications': None,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/378800000008579791/9daed4ae0181bf61d75928b4f59ee60c.jpeg',
#     'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/378800000008579791/9daed4ae0181bf61d75928b4f59ee60c.jpeg',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/18139461/1461955832',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/2815110476/033393c13e6dec0fd6cc5006453fbeb5_normal.png',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/2815110476/033393c13e6dec0fd6cc5006453fbeb5_normal.png',
#     'profile_link_color': '00611B',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': 'FFFFFF',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'celtics',
#     'statuses_count': 21999,
#     'time_zone': 'Eastern Time (US & Canada)',
#     'translator_type': 'none',
#     'url': 'http://t.co/fs0Hxtjf2C',
#     'utc_offset': -18000,
#     'verified': True}},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'text': "RT @celtics: Rozier's second straight 3-ball made it a 4-point game late in the third. https://t.co/kH1m512AVl",
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Wed Apr 20 20:18:35 +0000 2016',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'estamos en la bㅤ',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'twitter.com/daIessandr/sta…',
#        'expanded_url': 'https://twitter.com/daIessandr/status/808053856919781376',
#        'indices': [0, 23],
#        'url': 'https://t.co/nE81d0FpdX'}]}},
#    'favourites_count': 39,
#    'follow_request_sent': None,
#    'followers_count': 245,
#    'following': None,
#    'friends_count': 196,
#    'geo_enabled': True,
#    'has_extended_profile': True,
#    'id': 722882173469134849,
#    'id_str': '722882173469134849',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'pt',
#    'listed_count': 7,
#    'location': 'sci rmcf celtics',
#    'name': 'victor☘',
#    'notifications': None,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/837889839697641473/u-ZJghU1_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/837889839697641473/u-ZJghU1_normal.jpg',
#    'profile_link_color': '000000',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'protected': False,
#    'screen_name': 'daIessandr',
#    'statuses_count': 18272,
#    'time_zone': 'Brasilia',
#    'translator_type': 'none',
#    'url': 'https://t.co/nE81d0FpdX',
#    'utc_offset': -10800,
#    'verified': False}}]

# %%
# Does pretty much what its long name suggests.
def get_lots_of_tweets( latlong ):
    # Create a dictionary to parse the JSON
    all_tweets = {}
    
    # We will be hitting the API a number of times within the total time
    total_time = 1800
    
    # Everytime we hit the API we subtract time from the total
    remaining_seconds = total_time
    interval = 5
    while remaining_seconds > 0: # loop and run the function while remaining seconds is greater than zero
        added = 0
        # Hit the Twitter API using our function
        new_tweets = get_tweets_by_location(latlong) # we set latlong above!
        # Parse the resulting JSON, and save the rest of the raw content
        for tweet in new_tweets:
            tid = tweet['id']
            if tid not in all_tweets:
                properties = {}
                if tweet['coordinates'] != None:
                    properties['lat'] = tweet['coordinates']['coordinates'][0]
                    properties['lon'] = tweet['coordinates']['coordinates'][1]
                else:
                    properties['lat'] = None
                    properties['lon'] = None
                properties['location'] = tweet['user']['location'] #This will get us the location associated with the profile
                properties['tweet_id'] = tid
                properties['content'] = tweet['text']
                properties['user'] = tweet['user']['id']
                properties['raw_source'] = tweet
                properties['data_point'] = 'none'
                properties['time'] = tweet['created_at']
                all_tweets[ tid ] = properties
                added += 1
        print("At %d seconds, added %d new tweets, for a total of %d" % ( total_time - remaining_seconds, added, len( all_tweets )))
        # We wait a few seconds and hit the API again
        time.sleep(interval)
        remaining_seconds -= interval
    print(str(len(all_tweets)) + ' Tweets retrieved.')
    # We return the final dictionary to work with in Python
    return all_tweets

# %%
# This function executes the the functions over a given period of time
def run_all():
    # This is the number of times the code will be executed. In this case, just once. 
    starting = 1
    while starting > 0:
        # Sometimes the API returns some errors, killing the whole script, so we setup try/except to make sure it keeps running
        try:
            t = get_lots_of_tweets( latlong )
            # We name every file with the current time
            timestr = time.strftime("%Y%m%d-%H%M%S")
            # We write a new JSON into the target path
            with open( 'data/' + '%stweets.json' %(timestr), 'w' ) as f:
                f.write(json.dumps(t))
            # we can use a library like threading to execute the run function continuously.
            #threading.Timer(10, run).start()
            starting -= 1
        except:
            pass
    
run_all()
# Out:
# At 0 seconds, added 15 new tweets, for a total of 15
# At 5 seconds, added 0 new tweets, for a total of 15
# At 10 seconds, added 0 new tweets, for a total of 15
# At 15 seconds, added 0 new tweets, for a total of 15
# At 20 seconds, added 15 new tweets, for a total of 30
# At 25 seconds, added 0 new tweets, for a total of 30
# At 30 seconds, added 0 new tweets, for a total of 30
# At 35 seconds, added 0 new tweets, for a total of 30
# At 40 seconds, added 15 new tweets, for a total of 45
# At 45 seconds, added 0 new tweets, for a total of 45
# At 50 seconds, added 0 new tweets, for a total of 45
# At 55 seconds, added 0 new tweets, for a total of 45
# At 60 seconds, added 15 new tweets, for a total of 60
# At 65 seconds, added 0 new tweets, for a total of 60
# At 70 seconds, added 0 new tweets, for a total of 60
# At 75 seconds, added 0 new tweets, for a total of 60
# At 80 seconds, added 15 new tweets, for a total of 75
# At 85 seconds, added 0 new tweets, for a total of 75
# At 90 seconds, added 0 new tweets, for a total of 75
# At 95 seconds, added 0 new tweets, for a total of 75
# At 100 seconds, added 14 new tweets, for a total of 89
# At 105 seconds, added 0 new tweets, for a total of 89
# At 110 seconds, added 0 new tweets, for a total of 89
# At 115 seconds, added 0 new tweets, for a total of 89
# At 120 seconds, added 15 new tweets, for a total of 104
# At 125 seconds, added 0 new tweets, for a total of 104
# At 130 seconds, added 0 new tweets, for a total of 104
# At 135 seconds, added 0 new tweets, for a total of 104
# At 140 seconds, added 15 new tweets, for a total of 119
# At 145 seconds, added 0 new tweets, for a total of 119
# At 150 seconds, added 0 new tweets, for a total of 119
# At 155 seconds, added 0 new tweets, for a total of 119
# At 160 seconds, added 15 new tweets, for a total of 134
# At 165 seconds, added 0 new tweets, for a total of 134
# At 170 seconds, added 0 new tweets, for a total of 134
# At 175 seconds, added 0 new tweets, for a total of 134
# At 180 seconds, added 14 new tweets, for a total of 148
# At 185 seconds, added 0 new tweets, for a total of 148
# At 190 seconds, added 0 new tweets, for a total of 148
# At 195 seconds, added 0 new tweets, for a total of 148
# At 200 seconds, added 15 new tweets, for a total of 163
# At 205 seconds, added 0 new tweets, for a total of 163
# At 210 seconds, added 0 new tweets, for a total of 163
# At 215 seconds, added 0 new tweets, for a total of 163
# At 220 seconds, added 15 new tweets, for a total of 178
# At 225 seconds, added 0 new tweets, for a total of 178
# At 230 seconds, added 0 new tweets, for a total of 178
# At 235 seconds, added 0 new tweets, for a total of 178
# At 240 seconds, added 15 new tweets, for a total of 193
# At 245 seconds, added 0 new tweets, for a total of 193
# At 250 seconds, added 0 new tweets, for a total of 193
# At 255 seconds, added 0 new tweets, for a total of 193
# At 260 seconds, added 14 new tweets, for a total of 207
# At 265 seconds, added 0 new tweets, for a total of 207
# At 270 seconds, added 0 new tweets, for a total of 207
# At 275 seconds, added 0 new tweets, for a total of 207
# At 280 seconds, added 15 new tweets, for a total of 222
# At 285 seconds, added 0 new tweets, for a total of 222
# At 290 seconds, added 0 new tweets, for a total of 222
# At 295 seconds, added 0 new tweets, for a total of 222
# At 300 seconds, added 15 new tweets, for a total of 237
# At 305 seconds, added 0 new tweets, for a total of 237
# At 310 seconds, added 0 new tweets, for a total of 237
# At 315 seconds, added 0 new tweets, for a total of 237
# At 320 seconds, added 15 new tweets, for a total of 252
# At 325 seconds, added 0 new tweets, for a total of 252
# At 330 seconds, added 0 new tweets, for a total of 252
# At 335 seconds, added 0 new tweets, for a total of 252
# At 340 seconds, added 15 new tweets, for a total of 267
# At 345 seconds, added 0 new tweets, for a total of 267
# At 350 seconds, added 0 new tweets, for a total of 267
# At 355 seconds, added 0 new tweets, for a total of 267
# At 360 seconds, added 15 new tweets, for a total of 282
# At 365 seconds, added 0 new tweets, for a total of 282
# At 370 seconds, added 0 new tweets, for a total of 282
# At 375 seconds, added 0 new tweets, for a total of 282
# At 380 seconds, added 15 new tweets, for a total of 297
# At 385 seconds, added 0 new tweets, for a total of 297
# At 390 seconds, added 0 new tweets, for a total of 297
# At 395 seconds, added 0 new tweets, for a total of 297
# At 400 seconds, added 13 new tweets, for a total of 310
# At 405 seconds, added 0 new tweets, for a total of 310
# At 410 seconds, added 0 new tweets, for a total of 310
# At 415 seconds, added 0 new tweets, for a total of 310
# At 420 seconds, added 15 new tweets, for a total of 325
# At 425 seconds, added 0 new tweets, for a total of 325
# At 430 seconds, added 0 new tweets, for a total of 325
# At 435 seconds, added 0 new tweets, for a total of 325
# At 440 seconds, added 15 new tweets, for a total of 340
# At 445 seconds, added 0 new tweets, for a total of 340
# At 450 seconds, added 0 new tweets, for a total of 340
# At 455 seconds, added 0 new tweets, for a total of 340
# At 460 seconds, added 15 new tweets, for a total of 355
# At 465 seconds, added 0 new tweets, for a total of 355
# At 470 seconds, added 0 new tweets, for a total of 355
# At 475 seconds, added 0 new tweets, for a total of 355
# At 480 seconds, added 15 new tweets, for a total of 370
# At 485 seconds, added 0 new tweets, for a total of 370
# At 490 seconds, added 0 new tweets, for a total of 370
# At 495 seconds, added 0 new tweets, for a total of 370
# At 500 seconds, added 15 new tweets, for a total of 385
# At 505 seconds, added 0 new tweets, for a total of 385
# At 510 seconds, added 0 new tweets, for a total of 385
# At 515 seconds, added 0 new tweets, for a total of 385
# At 520 seconds, added 15 new tweets, for a total of 400
# At 525 seconds, added 0 new tweets, for a total of 400
# At 530 seconds, added 0 new tweets, for a total of 400
# At 535 seconds, added 0 new tweets, for a total of 400
# At 540 seconds, added 15 new tweets, for a total of 415
# At 545 seconds, added 0 new tweets, for a total of 415
# At 550 seconds, added 0 new tweets, for a total of 415
# At 555 seconds, added 0 new tweets, for a total of 415
# At 560 seconds, added 15 new tweets, for a total of 430
# At 565 seconds, added 0 new tweets, for a total of 430
# At 570 seconds, added 0 new tweets, for a total of 430
# At 575 seconds, added 0 new tweets, for a total of 430
# At 580 seconds, added 15 new tweets, for a total of 445
# At 585 seconds, added 0 new tweets, for a total of 445
# At 590 seconds, added 0 new tweets, for a total of 445
# At 595 seconds, added 0 new tweets, for a total of 445
# At 600 seconds, added 15 new tweets, for a total of 460
# At 605 seconds, added 0 new tweets, for a total of 460
# At 610 seconds, added 0 new tweets, for a total of 460
# At 615 seconds, added 0 new tweets, for a total of 460
# At 620 seconds, added 15 new tweets, for a total of 475
# At 625 seconds, added 0 new tweets, for a total of 475
# At 630 seconds, added 0 new tweets, for a total of 475
# At 635 seconds, added 0 new tweets, for a total of 475
# At 640 seconds, added 2 new tweets, for a total of 477
# At 645 seconds, added 0 new tweets, for a total of 477
# At 650 seconds, added 0 new tweets, for a total of 477
# At 655 seconds, added 0 new tweets, for a total of 477
# At 660 seconds, added 15 new tweets, for a total of 492
# At 665 seconds, added 0 new tweets, for a total of 492
# At 670 seconds, added 0 new tweets, for a total of 492
# At 675 seconds, added 0 new tweets, for a total of 492
# At 680 seconds, added 14 new tweets, for a total of 506
# At 685 seconds, added 0 new tweets, for a total of 506
# At 690 seconds, added 0 new tweets, for a total of 506
# At 695 seconds, added 0 new tweets, for a total of 506
# At 700 seconds, added 15 new tweets, for a total of 521
# At 705 seconds, added 0 new tweets, for a total of 521
# At 710 seconds, added 0 new tweets, for a total of 521
# At 715 seconds, added 0 new tweets, for a total of 521
# At 720 seconds, added 15 new tweets, for a total of 536
# At 725 seconds, added 0 new tweets, for a total of 536
# At 730 seconds, added 0 new tweets, for a total of 536
# At 735 seconds, added 0 new tweets, for a total of 536
# At 740 seconds, added 15 new tweets, for a total of 551
# At 745 seconds, added 0 new tweets, for a total of 551
# At 750 seconds, added 0 new tweets, for a total of 551
# At 755 seconds, added 0 new tweets, for a total of 551
# At 760 seconds, added 15 new tweets, for a total of 566
# At 765 seconds, added 0 new tweets, for a total of 566
# At 770 seconds, added 0 new tweets, for a total of 566
# At 775 seconds, added 0 new tweets, for a total of 566
# At 780 seconds, added 15 new tweets, for a total of 581
# At 785 seconds, added 0 new tweets, for a total of 581
# At 790 seconds, added 0 new tweets, for a total of 581
# At 795 seconds, added 0 new tweets, for a total of 581
# At 800 seconds, added 15 new tweets, for a total of 596
# At 805 seconds, added 0 new tweets, for a total of 596
# At 810 seconds, added 0 new tweets, for a total of 596
# At 815 seconds, added 0 new tweets, for a total of 596
# At 820 seconds, added 15 new tweets, for a total of 611
# At 825 seconds, added 0 new tweets, for a total of 611
# At 830 seconds, added 0 new tweets, for a total of 611
# At 835 seconds, added 0 new tweets, for a total of 611
# At 840 seconds, added 15 new tweets, for a total of 626
# At 845 seconds, added 0 new tweets, for a total of 626
# At 850 seconds, added 0 new tweets, for a total of 626
# At 855 seconds, added 0 new tweets, for a total of 626
# At 860 seconds, added 15 new tweets, for a total of 641
# At 865 seconds, added 0 new tweets, for a total of 641
# At 870 seconds, added 0 new tweets, for a total of 641
# At 875 seconds, added 0 new tweets, for a total of 641
# At 880 seconds, added 15 new tweets, for a total of 656
# At 885 seconds, added 0 new tweets, for a total of 656
# At 890 seconds, added 0 new tweets, for a total of 656
# At 895 seconds, added 0 new tweets, for a total of 656
# At 900 seconds, added 15 new tweets, for a total of 671
# At 905 seconds, added 0 new tweets, for a total of 671
# At 910 seconds, added 0 new tweets, for a total of 671
# At 915 seconds, added 0 new tweets, for a total of 671
# At 920 seconds, added 15 new tweets, for a total of 686
# At 925 seconds, added 0 new tweets, for a total of 686
# At 930 seconds, added 0 new tweets, for a total of 686
# At 935 seconds, added 0 new tweets, for a total of 686
# At 940 seconds, added 15 new tweets, for a total of 701
# At 945 seconds, added 0 new tweets, for a total of 701
# At 950 seconds, added 0 new tweets, for a total of 701
# At 955 seconds, added 0 new tweets, for a total of 701
# At 960 seconds, added 15 new tweets, for a total of 716
# At 965 seconds, added 0 new tweets, for a total of 716
# At 970 seconds, added 0 new tweets, for a total of 716
# At 975 seconds, added 0 new tweets, for a total of 716
# At 980 seconds, added 15 new tweets, for a total of 731
# At 985 seconds, added 0 new tweets, for a total of 731
# At 990 seconds, added 0 new tweets, for a total of 731
# At 995 seconds, added 0 new tweets, for a total of 731
# At 1000 seconds, added 15 new tweets, for a total of 746
# At 1005 seconds, added 0 new tweets, for a total of 746
# At 1010 seconds, added 0 new tweets, for a total of 746
# At 1015 seconds, added 0 new tweets, for a total of 746
# At 1020 seconds, added 14 new tweets, for a total of 760
# At 1025 seconds, added 0 new tweets, for a total of 760
# At 1030 seconds, added 0 new tweets, for a total of 760
# At 1035 seconds, added 0 new tweets, for a total of 760
# At 1040 seconds, added 12 new tweets, for a total of 772
# At 1045 seconds, added 0 new tweets, for a total of 772
# At 1050 seconds, added 0 new tweets, for a total of 772
# At 1055 seconds, added 0 new tweets, for a total of 772
# At 1060 seconds, added 14 new tweets, for a total of 786
# At 1065 seconds, added 0 new tweets, for a total of 786
# At 1070 seconds, added 0 new tweets, for a total of 786
# At 1075 seconds, added 0 new tweets, for a total of 786
# At 1080 seconds, added 15 new tweets, for a total of 801
# At 1085 seconds, added 0 new tweets, for a total of 801
# At 1090 seconds, added 0 new tweets, for a total of 801
# At 1095 seconds, added 0 new tweets, for a total of 801
# At 1100 seconds, added 15 new tweets, for a total of 816
# At 1105 seconds, added 0 new tweets, for a total of 816
# At 1110 seconds, added 1 new tweets, for a total of 817
# At 1115 seconds, added 0 new tweets, for a total of 817
# At 1120 seconds, added 15 new tweets, for a total of 832
# At 1125 seconds, added 15 new tweets, for a total of 847
# At 1130 seconds, added 0 new tweets, for a total of 847
# At 1135 seconds, added 0 new tweets, for a total of 847
# At 1140 seconds, added 0 new tweets, for a total of 847
# At 1145 seconds, added 13 new tweets, for a total of 860
# At 1150 seconds, added 0 new tweets, for a total of 860
# At 1155 seconds, added 0 new tweets, for a total of 860
# At 1160 seconds, added 0 new tweets, for a total of 860
# At 1165 seconds, added 14 new tweets, for a total of 874
# At 1170 seconds, added 0 new tweets, for a total of 874
# At 1175 seconds, added 0 new tweets, for a total of 874
# At 1180 seconds, added 0 new tweets, for a total of 874
# At 1185 seconds, added 15 new tweets, for a total of 889
# At 1190 seconds, added 0 new tweets, for a total of 889
# At 1195 seconds, added 0 new tweets, for a total of 889
# At 1200 seconds, added 0 new tweets, for a total of 889
# At 1205 seconds, added 15 new tweets, for a total of 904
# At 1210 seconds, added 0 new tweets, for a total of 904
# At 1215 seconds, added 0 new tweets, for a total of 904
# At 1220 seconds, added 0 new tweets, for a total of 904
# At 1225 seconds, added 15 new tweets, for a total of 919
# At 1230 seconds, added 0 new tweets, for a total of 919
# At 1235 seconds, added 0 new tweets, for a total of 919
# At 1240 seconds, added 0 new tweets, for a total of 919
# At 1245 seconds, added 15 new tweets, for a total of 934
# At 1250 seconds, added 0 new tweets, for a total of 934
# At 1255 seconds, added 0 new tweets, for a total of 934
# At 1260 seconds, added 0 new tweets, for a total of 934
# At 1265 seconds, added 15 new tweets, for a total of 949
# At 1270 seconds, added 0 new tweets, for a total of 949
# At 1275 seconds, added 0 new tweets, for a total of 949
# At 1280 seconds, added 0 new tweets, for a total of 949
# At 1285 seconds, added 14 new tweets, for a total of 963
# At 1290 seconds, added 0 new tweets, for a total of 963
# At 1295 seconds, added 0 new tweets, for a total of 963
# At 1300 seconds, added 0 new tweets, for a total of 963
# At 1305 seconds, added 15 new tweets, for a total of 978
# At 1310 seconds, added 0 new tweets, for a total of 978
# At 1315 seconds, added 0 new tweets, for a total of 978
# At 1320 seconds, added 0 new tweets, for a total of 978
# At 1325 seconds, added 15 new tweets, for a total of 993
# At 1330 seconds, added 0 new tweets, for a total of 993
# At 1335 seconds, added 0 new tweets, for a total of 993
# At 1340 seconds, added 0 new tweets, for a total of 993
# At 1345 seconds, added 15 new tweets, for a total of 1008
# At 1350 seconds, added 0 new tweets, for a total of 1008
# At 1355 seconds, added 0 new tweets, for a total of 1008
# At 1360 seconds, added 0 new tweets, for a total of 1008
# At 1365 seconds, added 15 new tweets, for a total of 1023
# At 1370 seconds, added 1 new tweets, for a total of 1024
# At 1375 seconds, added 0 new tweets, for a total of 1024
# At 1380 seconds, added 0 new tweets, for a total of 1024
# At 1385 seconds, added 15 new tweets, for a total of 1039
# At 1390 seconds, added 0 new tweets, for a total of 1039
# At 1395 seconds, added 0 new tweets, for a total of 1039
# At 1400 seconds, added 0 new tweets, for a total of 1039
# At 1405 seconds, added 14 new tweets, for a total of 1053
# At 1410 seconds, added 0 new tweets, for a total of 1053
# At 1415 seconds, added 0 new tweets, for a total of 1053
# At 1420 seconds, added 0 new tweets, for a total of 1053
# At 1425 seconds, added 15 new tweets, for a total of 1068
# At 1430 seconds, added 0 new tweets, for a total of 1068
# At 1435 seconds, added 0 new tweets, for a total of 1068
# At 1440 seconds, added 0 new tweets, for a total of 1068
# At 1445 seconds, added 15 new tweets, for a total of 1083
# At 1450 seconds, added 0 new tweets, for a total of 1083
# At 1455 seconds, added 0 new tweets, for a total of 1083
# At 1460 seconds, added 0 new tweets, for a total of 1083
# At 1465 seconds, added 15 new tweets, for a total of 1098
# At 1470 seconds, added 0 new tweets, for a total of 1098
# At 1475 seconds, added 0 new tweets, for a total of 1098
# At 1480 seconds, added 0 new tweets, for a total of 1098
# At 1485 seconds, added 15 new tweets, for a total of 1113
# At 1490 seconds, added 0 new tweets, for a total of 1113
# At 1495 seconds, added 0 new tweets, for a total of 1113
# At 1500 seconds, added 0 new tweets, for a total of 1113
# At 1505 seconds, added 15 new tweets, for a total of 1128
# At 1510 seconds, added 0 new tweets, for a total of 1128
# At 1515 seconds, added 0 new tweets, for a total of 1128
# At 1520 seconds, added 0 new tweets, for a total of 1128
# At 1525 seconds, added 15 new tweets, for a total of 1143
# At 1530 seconds, added 0 new tweets, for a total of 1143
# At 1535 seconds, added 0 new tweets, for a total of 1143
# At 1540 seconds, added 0 new tweets, for a total of 1143
# At 1545 seconds, added 15 new tweets, for a total of 1158
# At 1550 seconds, added 0 new tweets, for a total of 1158
# At 1555 seconds, added 0 new tweets, for a total of 1158
# At 1560 seconds, added 0 new tweets, for a total of 1158
# At 1565 seconds, added 15 new tweets, for a total of 1173
# At 1570 seconds, added 0 new tweets, for a total of 1173
# At 1575 seconds, added 0 new tweets, for a total of 1173
# At 1580 seconds, added 0 new tweets, for a total of 1173
# At 1585 seconds, added 15 new tweets, for a total of 1188
# At 1590 seconds, added 0 new tweets, for a total of 1188
# At 1595 seconds, added 0 new tweets, for a total of 1188
# At 1600 seconds, added 0 new tweets, for a total of 1188
# At 1605 seconds, added 15 new tweets, for a total of 1203
# At 1610 seconds, added 0 new tweets, for a total of 1203
# At 1615 seconds, added 0 new tweets, for a total of 1203
# At 1620 seconds, added 0 new tweets, for a total of 1203
# At 1625 seconds, added 15 new tweets, for a total of 1218
# At 1630 seconds, added 0 new tweets, for a total of 1218
# At 1635 seconds, added 0 new tweets, for a total of 1218
# At 1640 seconds, added 0 new tweets, for a total of 1218
# At 1645 seconds, added 15 new tweets, for a total of 1233
# At 1650 seconds, added 0 new tweets, for a total of 1233
# At 1655 seconds, added 0 new tweets, for a total of 1233
# At 1660 seconds, added 0 new tweets, for a total of 1233
# At 1665 seconds, added 15 new tweets, for a total of 1248
# At 1670 seconds, added 0 new tweets, for a total of 1248
# At 1675 seconds, added 0 new tweets, for a total of 1248
# At 1680 seconds, added 14 new tweets, for a total of 1262
# At 1685 seconds, added 0 new tweets, for a total of 1262
# At 1690 seconds, added 0 new tweets, for a total of 1262
# At 1695 seconds, added 0 new tweets, for a total of 1262
# At 1700 seconds, added 15 new tweets, for a total of 1277
# At 1705 seconds, added 0 new tweets, for a total of 1277
# At 1710 seconds, added 0 new tweets, for a total of 1277
# At 1715 seconds, added 0 new tweets, for a total of 1277
# At 1720 seconds, added 13 new tweets, for a total of 1290
# At 1725 seconds, added 0 new tweets, for a total of 1290
# At 1730 seconds, added 0 new tweets, for a total of 1290
# At 1735 seconds, added 0 new tweets, for a total of 1290
# At 1740 seconds, added 15 new tweets, for a total of 1305
# At 1745 seconds, added 0 new tweets, for a total of 1305
# At 1750 seconds, added 0 new tweets, for a total of 1305
# At 1755 seconds, added 0 new tweets, for a total of 1305
# At 1760 seconds, added 15 new tweets, for a total of 1320
# At 1765 seconds, added 0 new tweets, for a total of 1320
# At 1770 seconds, added 0 new tweets, for a total of 1320
# At 1775 seconds, added 0 new tweets, for a total of 1320
# At 1780 seconds, added 15 new tweets, for a total of 1335
# At 1785 seconds, added 0 new tweets, for a total of 1335
# At 1790 seconds, added 0 new tweets, for a total of 1335
# At 1795 seconds, added 0 new tweets, for a total of 1335
# 1335 Tweets retrieved.

# %%
# Import some additional libraries that will allow us to plot and interact with the operating system
from os import listdir
from os.path import isfile, join
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Get the file names from a given directory
file_dir = "data" # Set this to where your JSON saved
# Get only the JSONs we have saved
onlyfiles = [ f for f in listdir(file_dir) if isfile(join(file_dir,f)) and not f.startswith('.')]

# create an empty dataframe with columns for each property
df_tweets = pd.DataFrame(columns = ['tweet_id', 'lat', 'lon', 'content','location','user','raw_source','data_point','time'])

# Loop through all the files
for file in onlyfiles:
    full_dir = join(file_dir,file) 
    with open(full_dir) as json_data:
        dict = json.load(json_data) # creates a Python dictionary of our json
        if not isinstance(dict, list):
            for key, val in dict.items():
                df_tweets.loc[key,val] = val
                
df_tweets
# Out:
#                               tweet_id      lat      lon  \
# 836964415278718977  836964415278718977     None     None
# 836964383427284994  836964383427284994     None     None
# 836964370676596736  836964370676596736     None     None
# 836964370508824576  836964370508824576     None     None
# 836964361717628930  836964361717628930     None     None
# 836964342289543168  836964342289543168     None     None
# 836964334005862400  836964334005862400     None     None
# 836964333192097792  836964333192097792     None     None
# 836964328653778944  836964328653778944     None     None
# 836964328620322816  836964328620322816     None     None
# 836964328360267776  836964328360267776     None     None
# 836964312275116032  836964312275116032     None     None
# 836964311562088448  836964311562088448     None     None
# 836964303773237248  836964303773237248     None     None
# 836964301709664256  836964301709664256     None     None
# 838533971575246850  838533971575246850     None     None
# 838533956991660033  838533956991660033     None     None
# 838533954714144768  838533954714144768     None     None
# 838533954139480064  838533954139480064 -76.8433   40.261
# 838533945801191430  838533945801191430     None     None
# 838533929418248192  838533929418248192     None     None
# 838533917405761536  838533917405761536     None     None
# 838533891992477696  838533891992477696 -76.5624  40.0559
# 838533888473509889  838533888473509889     None     None
# 838533873097125888  838533873097125888     None     None
# 838533864243007488  838533864243007488     None     None
# 838533845075046401  838533845075046401     None     None
# 838533824724205568  838533824724205568     None     None
# 838533821863706625  838533821863706625     None     None
# 838533773448757248  838533773448757248 -76.6512  40.2784
# ...                                ...      ...      ...
# 838550036069896192  838550036069896192     None     None
# 838550034534785024  838550034534785024     None     None
# 838550034266406916  838550034266406916     None     None
# 838550034241171456  838550034241171456     None     None
# 838550033507225600  838550033507225600     None     None
# 838550031791706116  838550031791706116     None     None
# 838550031040933889  838550031040933889     None     None
# 838550030055321601  838550030055321601     None     None
# 838550028604047361  838550028604047361     None     None
# 838550027073122304  838550027073122304     None     None
# 838550026704076800  838550026704076800     None     None
# 838550026041204737  838550026041204737     None     None
# 838550025781174272  838550025781174272     None     None
# 838550023881244672  838550023881244672     None     None
# 838550020534251520  838550020534251520     None     None
# 838550125005897728  838550125005897728     None     None
# 838550123579846657  838550123579846657     None     None
# 838550123227529217  838550123227529217     None     None
# 838550123063963648  838550123063963648     None     None
# 838550123063959552  838550123063959552     None     None
# 838550122875203584  838550122875203584     None     None
# 838550122665504769  838550122665504769     None     None
# 838550121373712384  838550121373712384     None     None
# 838550121361002496  838550121361002496     None     None
# 838550121344339968  838550121344339968     None     None
# 838550120102834176  838550120102834176     None     None
# 838550119972732928  838550119972732928     None     None
# 838550118345420802  838550118345420802     None     None
# 838550117049323520  838550117049323520     None     None
# 838550116931940352  838550116931940352     None     None
#
#                                                               content  \
# 836964415278718977  RT @realJeffreyLord: Trump critic Van Jones: ‘...
# 836964383427284994  WEATHER ALERT: A Severe Storm WATCH in effect ...
# 836964370676596736  RT @PADeptofEd: “My budget puts kids first” ➡️...
# 836964370508824576  Personalizing educator professional developmen...
# 836964361717628930  RT @realJeffreyLord: Yes. Exactly. https://t.c...
# 836964342289543168  #CarMaintenance Tips for the First Time E-Car ...
# 836964334005862400  How?? It's our fault for paying her or even co...
# 836964333192097792  Are you prepared if a severe storm strikes in ...
# 836964328653778944              RT @debasesu: https://t.co/e9RJmruzjZ
# 836964328620322816  @sydneifryson Check out some of our favorite #...
# 836964328360267776  @TymothyLongoria @acthomasbooks @ShelfAwarenes...
# 836964312275116032  I posted a new photo to Facebook https://t.co/...
# 836964311562088448  RT @We_Are_Penn_St: @FoxNews @POTUS @DeptofDef...
# 836964303773237248  This is why personalized PD is relevant. #macp...
# 836964301709664256  @travlingtheroad @marcuslemonis where was the ...
# 838533971575246850  My level of pettiness toward RM extends to FEU...
# 838533956991660033  getting lighter and lighter.  Then the seat in...
# 838533954714144768  A little #Throwback: How To Start Seeds In Egg...
# 838533954139480064  Whoa! Glad I'm having smoked steak! This need....
# 838533945801191430  @tessav87 It's OK, Tess! :) You're also very s...
# 838533929418248192         RT @msannyy: X2 🍭✨ https://t.co/a2WdEPhH83
# 838533917405761536  When you hate homework😒 but don't wanna fail  ...
# 838533891992477696  #bigmuddybrewing #galaxy #ipa #nicksbistro #ma...
# 838533888473509889            The hill is now closed for the evening.
# 838533873097125888  Here's another "Outfit of the Day"\n(XXS) Carl...
# 838533864243007488  The “moral test” facing Los Angeles over depor...
# 838533845075046401  If Trump doesn't stop "crying wolf"with ridicu...
# 838533824724205568  Internally screaming at work right now. Yas qu...
# 838533821863706625  Israel marijuana: Users to face fine rather th...
# 838533773448757248  all smiles when I'm with my bff💗 @ Hershey, Pe...
# ...                                                               ...
# 838550036069896192               LMAO MICHAEL COLE LOOKS SO PERPLEXED
# 838550034534785024  Dying to get out of work to smoke a fat wood a...
# 838550034266406916       (99) MASA - Timeline https://t.co/rwCjraxZPs
# 838550034241171456   He hasn't been wrong yet https://t.co/MkKgcEBlLd
# 838550033507225600  RT @CelticsDirect: What an incredible ending.....
# 838550031791706116                    Dispute https://t.co/cVS6A0YkJf
# 838550031040933889  G3K5 [the droid formerly known as "bad and bou...
# 838550030055321601  RT @CelticsDirect: What an incredible ending.....
# 838550028604047361  RT @TheBpDShow: Holy crap that is amazing @jpa...
# 838550027073122304  @MattAshton81 @coldanalytics the plan is most ...
# 838550026704076800                   @Isabella_B_T  you know I am lol
# 838550026041204737  RT @OnlyInBOS: One month ago today... https://...
# 838550025781174272  RT @ValaAfshar: Dear successful person,\n\nYou...
# 838550023881244672  Young Mädchen Amick spotted on TNG, looked it ...
# 838550020534251520                           @kyuubified DEAD GOODBYE
# 838550125005897728  Beaware! NEVER Eat At These Restaurants! You H...
# 838550123579846657  @Karyxt_ The only 13's that are nice are the F...
# 838550123227529217  Nav look like a young Dj Khaled https://t.co/p...
# 838550123063963648  Congratulations to Catholic Conference MVP Car...
# 838550123063959552                  Knicks lead 5-4 after one segment
# 838550122875203584  RT @CelticsDirect: What an incredible ending.....
# 838550122665504769  @DatRaginCajun this actually sounds like a goo...
# 838550121373712384  RT @CelticsDirect: What an incredible ending.....
# 838550121361002496  @isaacfromCT @ESPNForsberg 2 best players out ...
# 838550121344339968  @LlegoLaPatilla_ But do you have a business ca...
# 838550120102834176  RT @CelticsDirect: What an incredible ending.....
# 838550119972732928                    RT @Ndu_pops: Humans are weird😂
# 838550118345420802          @feryate Thank you for this gem of a song
# 838550117049323520  RT @CelticsDirect: What an incredible ending.....
# 838550116931940352                     Left my fucking wallet at work
#
#                                      location                user  \
# 836964415278718977          Newport Beach, CA            20730083
# 836964383427284994             Harrisburg, PA          2473829791
# 836964370676596736           Philadelphia, PA          3631050620
# 836964370508824576          Mechanicsburg, PA  835912294731239424
# 836964361717628930                       OHIO           247036262
# 836964342289543168               Carlisle, PA          3252470211
# 836964334005862400             Harrisburg, PA           245175488
# 836964333192097792             Harrisburg, PA          3218464527
# 836964328653778944                   Mesa, AZ          2191808276
# 836964328620322816             Harrisburg, PA  836244015490056192
# 836964328360267776              Highspire, PA           127707068
# 836964312275116032              Jonestown, PA          2290345160
# 836964311562088448        Bay, Gulf of Mexico          2952557518
# 836964303773237248                Manheim, PA          4097398883
# 836964301709664256               Hershey, PA           2584490635
# 838533971575246850           Wrightsville, PA           311219239
# 838533956991660033              Mount Joy, PA          2357518183
# 838533954714144768                   York, PA            21632854
# 838533954139480064            Linglestown, PA          2423758021
# 838533945801191430              Grantville,PA          1873757142
# 838533929418248192                             694694887409647618
# 838533917405761536            Harrisburg , PA          2970479398
# 838533891992477696               Marietta, PA           387974372
# 838533888473509889                Lebanon, Pa          4359999974
# 838533873097125888                   York, PA  813570323681570817
# 838533864243007488                 Harrisburg           741384337
# 838533845075046401                                      252098575
# 838533824724205568          Elizabethtown, Pa           526798667
# 838533821863706625          Elizabethtown, PA           373073651
# 838533773448757248                         PA           615275045
# ...                                       ...                 ...
# 838550036069896192                 Boston, MA           609337185
# 838550034534785024                 Dracut, MA          3516013575
# 838550034266406916         Winchester, MA USA            51276346
# 838550034241171456         Massachusetts, USA            16677181
# 838550033507225600                                     3070968094
# 838550031791706116                  Quincy Ma           338559732
# 838550031040933889                 Boston, MA  816724596057632768
# 838550030055321601               Latvija,Rīga           449702755
# 838550028604047361               Montana, USA          2177428656
# 838550027073122304                 Boston, MA           155210725
# 838550026704076800                 Norton, MA  803018505750802433
# 838550026041204737                                     1212774301
# 838550025781174272            Los Angeles, CA           398341971
# 838550023881244672  Somerville, Massachusetts            96630001
# 838550020534251520                     Boston            31077743
# 838550125005897728                 Lowell, MA  822711451999555584
# 838550123579846657   Charlestown | Boston, MA           344538894
# 838550123227529217                  Boston,MA           305331852
# 838550123063963648                  Boston,Ma          2783056566
# 838550123063959552             Chelmsford, MA  798208864697061376
# 838550122875203584                                     3136154376
# 838550122665504769                 Boston, MA          1340403733
# 838550121373712384                                     2304534496
# 838550121361002496                 Boston, MA           966810078
# 838550121344339968                Chelsea, MA           619489844
# 838550120102834176                                      518057086
# 838550119972732928               South Africa           600193861
# 838550118345420802                 Revere, MA            26365210
# 838550117049323520                                      463137917
# 838550116931940352                 Boston, MA  768314809058226176
#
#                                                            raw_source  \
# 836964415278718977  {'created_at': 'Wed Mar 01 15:40:41 +0000 2017...
# 836964383427284994  {'created_at': 'Wed Mar 01 15:40:33 +0000 2017...
# 836964370676596736  {'created_at': 'Wed Mar 01 15:40:30 +0000 2017...
# 836964370508824576  {'created_at': 'Wed Mar 01 15:40:30 +0000 2017...
# 836964361717628930  {'created_at': 'Wed Mar 01 15:40:28 +0000 2017...
# 836964342289543168  {'created_at': 'Wed Mar 01 15:40:23 +0000 2017...
# 836964334005862400  {'created_at': 'Wed Mar 01 15:40:21 +0000 2017...
# 836964333192097792  {'created_at': 'Wed Mar 01 15:40:21 +0000 2017...
# 836964328653778944  {'created_at': 'Wed Mar 01 15:40:20 +0000 2017...
# 836964328620322816  {'created_at': 'Wed Mar 01 15:40:20 +0000 2017...
# 836964328360267776  {'created_at': 'Wed Mar 01 15:40:20 +0000 2017...
# 836964312275116032  {'created_at': 'Wed Mar 01 15:40:16 +0000 2017...
# 836964311562088448  {'created_at': 'Wed Mar 01 15:40:16 +0000 2017...
# 836964303773237248  {'created_at': 'Wed Mar 01 15:40:14 +0000 2017...
# 836964301709664256  {'created_at': 'Wed Mar 01 15:40:14 +0000 2017...
# 838533971575246850  {'created_at': 'Sun Mar 05 23:37:32 +0000 2017...
# 838533956991660033  {'created_at': 'Sun Mar 05 23:37:29 +0000 2017...
# 838533954714144768  {'created_at': 'Sun Mar 05 23:37:28 +0000 2017...
# 838533954139480064  {'created_at': 'Sun Mar 05 23:37:28 +0000 2017...
# 838533945801191430  {'created_at': 'Sun Mar 05 23:37:26 +0000 2017...
# 838533929418248192  {'created_at': 'Sun Mar 05 23:37:22 +0000 2017...
# 838533917405761536  {'created_at': 'Sun Mar 05 23:37:19 +0000 2017...
# 838533891992477696  {'created_at': 'Sun Mar 05 23:37:13 +0000 2017...
# 838533888473509889  {'created_at': 'Sun Mar 05 23:37:12 +0000 2017...
# 838533873097125888  {'created_at': 'Sun Mar 05 23:37:09 +0000 2017...
# 838533864243007488  {'created_at': 'Sun Mar 05 23:37:07 +0000 2017...
# 838533845075046401  {'created_at': 'Sun Mar 05 23:37:02 +0000 2017...
# 838533824724205568  {'created_at': 'Sun Mar 05 23:36:57 +0000 2017...
# 838533821863706625  {'created_at': 'Sun Mar 05 23:36:56 +0000 2017...
# 838533773448757248  {'created_at': 'Sun Mar 05 23:36:45 +0000 2017...
# ...                                                               ...
# 838550036069896192  {'created_at': 'Mon Mar 06 00:41:22 +0000 2017...
# 838550034534785024  {'created_at': 'Mon Mar 06 00:41:22 +0000 2017...
# 838550034266406916  {'created_at': 'Mon Mar 06 00:41:22 +0000 2017...
# 838550034241171456  {'created_at': 'Mon Mar 06 00:41:22 +0000 2017...
# 838550033507225600  {'created_at': 'Mon Mar 06 00:41:22 +0000 2017...
# 838550031791706116  {'created_at': 'Mon Mar 06 00:41:21 +0000 2017...
# 838550031040933889  {'created_at': 'Mon Mar 06 00:41:21 +0000 2017...
# 838550030055321601  {'created_at': 'Mon Mar 06 00:41:21 +0000 2017...
# 838550028604047361  {'created_at': 'Mon Mar 06 00:41:20 +0000 2017...
# 838550027073122304  {'created_at': 'Mon Mar 06 00:41:20 +0000 2017...
# 838550026704076800  {'created_at': 'Mon Mar 06 00:41:20 +0000 2017...
# 838550026041204737  {'created_at': 'Mon Mar 06 00:41:20 +0000 2017...
# 838550025781174272  {'created_at': 'Mon Mar 06 00:41:20 +0000 2017...
# 838550023881244672  {'created_at': 'Mon Mar 06 00:41:19 +0000 2017...
# 838550020534251520  {'created_at': 'Mon Mar 06 00:41:19 +0000 2017...
# 838550125005897728  {'created_at': 'Mon Mar 06 00:41:43 +0000 2017...
# 838550123579846657  {'created_at': 'Mon Mar 06 00:41:43 +0000 2017...
# 838550123227529217  {'created_at': 'Mon Mar 06 00:41:43 +0000 2017...
# 838550123063963648  {'created_at': 'Mon Mar 06 00:41:43 +0000 2017...
# 838550123063959552  {'created_at': 'Mon Mar 06 00:41:43 +0000 2017...
# 838550122875203584  {'created_at': 'Mon Mar 06 00:41:43 +0000 2017...
# 838550122665504769  {'created_at': 'Mon Mar 06 00:41:43 +0000 2017...
# 838550121373712384  {'created_at': 'Mon Mar 06 00:41:43 +0000 2017...
# 838550121361002496  {'created_at': 'Mon Mar 06 00:41:43 +0000 2017...
# 838550121344339968  {'created_at': 'Mon Mar 06 00:41:43 +0000 2017...
# 838550120102834176  {'created_at': 'Mon Mar 06 00:41:42 +0000 2017...
# 838550119972732928  {'created_at': 'Mon Mar 06 00:41:42 +0000 2017...
# 838550118345420802  {'created_at': 'Mon Mar 06 00:41:42 +0000 2017...
# 838550117049323520  {'created_at': 'Mon Mar 06 00:41:42 +0000 2017...
# 838550116931940352  {'created_at': 'Mon Mar 06 00:41:42 +0000 2017...
#
#                    data_point                            time
# 836964415278718977       none  Wed Mar 01 15:40:41 +0000 2017
# 836964383427284994       none  Wed Mar 01 15:40:33 +0000 2017
# 836964370676596736       none  Wed Mar 01 15:40:30 +0000 2017
# 836964370508824576       none  Wed Mar 01 15:40:30 +0000 2017
# 836964361717628930       none  Wed Mar 01 15:40:28 +0000 2017
# 836964342289543168       none  Wed Mar 01 15:40:23 +0000 2017
# 836964334005862400       none  Wed Mar 01 15:40:21 +0000 2017
# 836964333192097792       none  Wed Mar 01 15:40:21 +0000 2017
# 836964328653778944       none  Wed Mar 01 15:40:20 +0000 2017
# 836964328620322816       none  Wed Mar 01 15:40:20 +0000 2017
# 836964328360267776       none  Wed Mar 01 15:40:20 +0000 2017
# 836964312275116032       none  Wed Mar 01 15:40:16 +0000 2017
# 836964311562088448       none  Wed Mar 01 15:40:16 +0000 2017
# 836964303773237248       none  Wed Mar 01 15:40:14 +0000 2017
# 836964301709664256       none  Wed Mar 01 15:40:14 +0000 2017
# 838533971575246850       none  Sun Mar 05 23:37:32 +0000 2017
# 838533956991660033       none  Sun Mar 05 23:37:29 +0000 2017
# 838533954714144768       none  Sun Mar 05 23:37:28 +0000 2017
# 838533954139480064       none  Sun Mar 05 23:37:28 +0000 2017
# 838533945801191430       none  Sun Mar 05 23:37:26 +0000 2017
# 838533929418248192       none  Sun Mar 05 23:37:22 +0000 2017
# 838533917405761536       none  Sun Mar 05 23:37:19 +0000 2017
# 838533891992477696       none  Sun Mar 05 23:37:13 +0000 2017
# 838533888473509889       none  Sun Mar 05 23:37:12 +0000 2017
# 838533873097125888       none  Sun Mar 05 23:37:09 +0000 2017
# 838533864243007488       none  Sun Mar 05 23:37:07 +0000 2017
# 838533845075046401       none  Sun Mar 05 23:37:02 +0000 2017
# 838533824724205568       none  Sun Mar 05 23:36:57 +0000 2017
# 838533821863706625       none  Sun Mar 05 23:36:56 +0000 2017
# 838533773448757248       none  Sun Mar 05 23:36:45 +0000 2017
# ...                       ...                             ...
# 838550036069896192       none  Mon Mar 06 00:41:22 +0000 2017
# 838550034534785024       none  Mon Mar 06 00:41:22 +0000 2017
# 838550034266406916       none  Mon Mar 06 00:41:22 +0000 2017
# 838550034241171456       none  Mon Mar 06 00:41:22 +0000 2017
# 838550033507225600       none  Mon Mar 06 00:41:22 +0000 2017
# 838550031791706116       none  Mon Mar 06 00:41:21 +0000 2017
# 838550031040933889       none  Mon Mar 06 00:41:21 +0000 2017
# 838550030055321601       none  Mon Mar 06 00:41:21 +0000 2017
# 838550028604047361       none  Mon Mar 06 00:41:20 +0000 2017
# 838550027073122304       none  Mon Mar 06 00:41:20 +0000 2017
# 838550026704076800       none  Mon Mar 06 00:41:20 +0000 2017
# 838550026041204737       none  Mon Mar 06 00:41:20 +0000 2017
# 838550025781174272       none  Mon Mar 06 00:41:20 +0000 2017
# 838550023881244672       none  Mon Mar 06 00:41:19 +0000 2017
# 838550020534251520       none  Mon Mar 06 00:41:19 +0000 2017
# 838550125005897728       none  Mon Mar 06 00:41:43 +0000 2017
# 838550123579846657       none  Mon Mar 06 00:41:43 +0000 2017
# 838550123227529217       none  Mon Mar 06 00:41:43 +0000 2017
# 838550123063963648       none  Mon Mar 06 00:41:43 +0000 2017
# 838550123063959552       none  Mon Mar 06 00:41:43 +0000 2017
# 838550122875203584       none  Mon Mar 06 00:41:43 +0000 2017
# 838550122665504769       none  Mon Mar 06 00:41:43 +0000 2017
# 838550121373712384       none  Mon Mar 06 00:41:43 +0000 2017
# 838550121361002496       none  Mon Mar 06 00:41:43 +0000 2017
# 838550121344339968       none  Mon Mar 06 00:41:43 +0000 2017
# 838550120102834176       none  Mon Mar 06 00:41:42 +0000 2017
# 838550119972732928       none  Mon Mar 06 00:41:42 +0000 2017
# 838550118345420802       none  Mon Mar 06 00:41:42 +0000 2017
# 838550117049323520       none  Mon Mar 06 00:41:42 +0000 2017
# 838550116931940352       none  Mon Mar 06 00:41:42 +0000 2017
#
# [1365 rows x 9 columns]
